# %% [markdown]
# # proxy.ipynb — Colab MCP pipeline smoke test
# Minimal cells to validate the add/run/read loop over the Colab MCP bridge before driving the real notebook.

# %%
print('hello from colab-mcp')
print('2 + 2 =', 2 + 2)

# %%
import sys, platform
print('python', sys.version.split()[0], '|', platform.platform())

# %%
import subprocess, shutil
if shutil.which('nvidia-smi'):
    print(subprocess.run(['nvidia-smi', '-L'], capture_output=True, text=True).stdout)
else:
    print('GPU visible: False (CPU runtime) - set Runtime -> Change runtime type -> GPU')
