# %% [markdown]
# # Setup

# %%
from datetime import timedelta
import json, heapq, itertools, csv
import time
import datetime
from datetime import datetime, timezone
import os
import tqdm
import pickle
import numpy as np
import pandas as pd
import random
import networkx as nx
from matplotlib import pyplot as plt
import seaborn as sns
import re, string
from collections import OrderedDict
# !pip install langdetect
# from langdetect import detect_langs
# langdetect.DetectorFactory.seed = 0

from pathlib import Path
from google.colab import drive
# drive.mount('/content/drive')

# %%
# ──────────────────────────────────────────────────────────────────────────────
# 1. Drive Mount & Paths
# ──────────────────────────────────────────────────────────────────────────────
drive.mount('/content/drive')

# Base project folder (Ignacio standard)
# BASE = Path('/content/drive/My Drive/Colab Projects/AI Public Trust')
BASE = Path('/content/drive/My Drive/AI Public Trust')

twits_folder = BASE / 'Raw Data/Twits/'
test_folder = BASE / 'Raw Data/'
print("Current Directory:", twits_folder)
datasets_folder = BASE / 'Data Sets'
cleanedds_folder = BASE / 'Data Sets' / 'Cleaned Data'
networks_folder = BASE / 'Data Sets' / 'Networks'
# Out:
# Mounted at /content/drive
# Current Directory: /content/drive/My Drive/AI Public Trust/Raw Data/Twits

# %% [markdown]
# # Sanity Check

# %% [markdown]
# ## Sanity Check Test

# %%
# Check how it looks, LINE BY LINE
# CHECKING FOR TYPES OF TWEET THAT ARE NOT ORIGINAL
AItrust_twits_dict_test = open(cleanedds_folder/'AItrust_twits_dict_test.json','r',encoding='utf-8')

i = 0
for line in AItrust_twits_dict_test:
    twit = json.loads(line)
    #print(twit)
    try:
      i+=1
      print(twit['referenced_tweets'])
      print(twit['type'])
      print(twit.keys())
      print('------')
    except:
      pass
    #print('------')
    if i>5:
        break
AItrust_twits_dict_test.close()
# Out:
# 1592178048002326529
# retweeted
# dict_keys(['id', 'text', 'created_at', 'public_metrics', 'author_id', 'type', 'referenced_tweets', 'conversation_id', 'referenced_tweets_dictionary'])
# ------
# 1592187343351463936
# replied_to
# dict_keys(['id', 'text', 'created_at', 'public_metrics', 'author_id', 'type', 'referenced_tweets', 'conversation_id', 'referenced_tweets_dictionary'])
# ------
# 1591860196737175553
# replied_to
# dict_keys(['id', 'text', 'created_at', 'public_metrics', 'author_id', 'type', 'referenced_tweets', 'conversation_id', 'referenced_tweets_dictionary'])
# ------

# %%
# Check how it looks, LINE BY LINE
# dict_keys(['description', 'public_metrics', 'created_at', 'id', 'entities', 'name', 'username', 'verified'])
AItrust_author_dict_test = open(cleanedds_folder/'AItrust_author_dict_test.json','r',encoding='utf-8')

i = 0
for line in AItrust_author_dict_test:
    i+=1
    author = json.loads(line)
    print(author.keys())
    print(author['verified'])
    if i>10:
        break
AItrust_author_dict_test.close()
# Out:
# dict_keys(['description', 'public_metrics', 'created_at', 'id', 'entities', 'name', 'username', 'verified'])
# False
# dict_keys(['description', 'public_metrics', 'created_at', 'id', 'entities', 'name', 'username', 'verified'])
# False
# dict_keys(['description', 'public_metrics', 'created_at', 'id', 'entities', 'name', 'username', 'verified', 'location'])
# False
# dict_keys(['description', 'public_metrics', 'created_at', 'id', 'name', 'username', 'verified'])
# False
# dict_keys(['description', 'public_metrics', 'created_at', 'id', 'entities', 'name', 'username', 'verified'])
# False
# dict_keys(['description', 'public_metrics', 'created_at', 'id', 'entities', 'name', 'username', 'verified', 'location'])
# True
# dict_keys(['description', 'public_metrics', 'created_at', 'id', 'entities', 'name', 'username', 'verified', 'location'])
# False
# dict_keys(['description', 'public_metrics', 'created_at', 'id', 'name', 'username', 'verified'])
# False
# dict_keys(['description', 'public_metrics', 'created_at', 'id', 'entities', 'name', 'username', 'verified'])
# False
# dict_keys(['description', 'public_metrics', 'created_at', 'id', 'entities', 'name', 'username', 'verified', 'location'])
# False
# dict_keys(['description', 'public_metrics', 'created_at', 'id', 'entities', 'name', 'username', 'verified', 'location'])
# True

# %% [markdown]
# ## Sanity Test Full

# %%
# Check how it looks, LINE BY LINE
# CHECKING FOR TYPES OF TWEET THAT ARE NOT ORIGINAL
AItrust_twits_dict = open(cleanedds_folder/'AItrust_twits_dict.json','r',encoding='utf-8')

i = 0
for line in AItrust_twits_dict:
    twit = json.loads(line)
    #print(twit)
    try:
      i+=1
      print(twit['referenced_tweets'])
      print(twit['type'])
      print(twit.keys())
      print('------')
    except:
      pass
    #print('------')
    if i>5:
        break
AItrust_twits_dict.close()
# Out:
# 1622638090752753679
# retweeted
# dict_keys(['id', 'text', 'created_at', 'public_metrics', 'author_id', 'type', 'referenced_tweets', 'conversation_id', 'referenced_tweets_dictionary'])
# ------
# 1622280318861418497
# retweeted
# dict_keys(['id', 'text', 'created_at', 'public_metrics', 'author_id', 'type', 'referenced_tweets', 'conversation_id', 'referenced_tweets_dictionary'])
# ------
# 1622609955411861506
# retweeted
# dict_keys(['id', 'text', 'created_at', 'public_metrics', 'author_id', 'type', 'referenced_tweets', 'conversation_id', 'referenced_tweets_dictionary'])
# ------

# %%
# Check how it looks, LINE BY LINE
# CHECKING FOR TYPES OF TWEET THAT ARE NOT ORIGINAL
AItrust_author_dict = open(cleanedds_folder/'AItrust_author_dict.json','r',encoding='utf-8')

i = 0
for line in AItrust_author_dict:
    i+=1
    author = json.loads(line)
    print(author.keys())
    print(author['verified'])
    print(author['public_metrics'])
    if i>5:
        break
AItrust_author_dict.close()
# Out:
# dict_keys(['description', 'created_at', 'location', 'id', 'username', 'verified', 'name', 'public_metrics', 'entities'])
# False
# {'followers_count': 70, 'following_count': 1228, 'tweet_count': 1931, 'listed_count': 0}
# dict_keys(['description', 'created_at', 'location', 'id', 'username', 'verified', 'name', 'public_metrics', 'entities'])
# False
# {'followers_count': 5628, 'following_count': 5856, 'tweet_count': 36333, 'listed_count': 12}
# dict_keys(['description', 'created_at', 'location', 'id', 'username', 'verified', 'name', 'public_metrics', 'entities'])
# True
# {'followers_count': 20700, 'following_count': 397, 'tweet_count': 1511, 'listed_count': 16}
# dict_keys(['description', 'created_at', 'location', 'id', 'username', 'verified', 'name', 'public_metrics'])
# True
# {'followers_count': 26, 'following_count': 123, 'tweet_count': 372, 'listed_count': 2}
# dict_keys(['description', 'created_at', 'location', 'id', 'username', 'verified', 'name', 'public_metrics', 'entities'])
# True
# {'followers_count': 2845539, 'following_count': 34, 'tweet_count': 2714, 'listed_count': 8636}
# dict_keys(['description', 'created_at', 'location', 'id', 'username', 'verified', 'name', 'public_metrics'])
# False
# {'followers_count': 71, 'following_count': 300, 'tweet_count': 747, 'listed_count': 2}

# %% [markdown]
# # Prunning by Date and Content
#
# I have noticed that there is a lot of rubbish that we want to avoid analysing, and deserves prunning:
# - If a tweet about AI refers (retweets, quotes, replies) a tweet before our cutoff date, it will appear in the dataset.
# - If a tweet about AI refers a tweet that contains no AI terminology, it will still appear in our dataset.
#
# So I will remove all tweets with no AI language, and before our cutoff date.

# %% [markdown]
# ## Prunning Functions

# %%
# # --- Core keywords (NO bare AI/AGI here) ------------------------------------
# # We exclude bare "AI"/"AGI" because they're too permissive ("daily", "aging").
# # Instead, we handle them explicitly with _RE_AI_ALLOWED/_RE_AGI_ALLOWED below.
# pattern = re.compile(
#     r'(?:'                                 # group of alternatives
#         r'\bChatGPT\b|'
#         r'\bChat-GPT\b|'
#         r'\bGPT(?:-?3|-?4)?\b|'            # GPT, GPT3, GPT-3, GPT4, GPT-4
#         r'\bLLMs?\b|'                      # LLM, LLMs
#         r'\bBARD\b|'
#         r'\bBERT\b|'
#         r'\bLaMDA\b|'
#         r'\bPaLM\b|'
#         r'\bLLaMA\b|'
#         r'\bMed-PaLM\b|'
#         r'Bing AI|'                        # phrase
#         r'artificial intelligence|'        # phrase
#         r'large language models'           # phrase
#     r')',
#     re.IGNORECASE
# )

# # --- Allowed AI/AGI forms ----------------------------------------------------
# # ✅ Allowed (examples):
# #   AI / #AI / #AIart / @AI_news / AI-powered
# #   AGI / #AGI / #AGI-safety / @AGIteam / AGI-related
# #
# # ❌ Rejected:
# #   "again", "brain", "aging", "engaging" (embedded 'ai'/'agi' inside words)
# _RE_AI_ALLOWED  = re.compile(r'(?:\bAI\b|#AI[\w-]*|@AI[\w-]*|AI-[A-Za-z])',   re.IGNORECASE)
# _RE_AGI_ALLOWED = re.compile(r'(?:\bAGI\b|#AGI[\w-]*|@AGI[\w-]*|AGI-[A-Za-z])', re.IGNORECASE)

# # --- Denylist for spammy tokens ----------------------------------------------
# # These strings look like allowed forms but are NOT genuine AI/AGI keywords.
# # Example: "#Airdrop" matches "#AI…" but should be rejected.
# AI_DENYLIST = {"#airdrop", "@airdrop"}

# def has_allowed_ai_form(txt: str) -> bool:
#     """
#     Returns True if the text contains an allowed AI form
#     (standalone, hashtag, mention, hyphen), but not if it's in the denylist.
#     """
#     if _RE_AI_ALLOWED.search(txt):
#         for tok in re.findall(r'[@#][A-Za-z0-9_-]+', txt):
#             if tok.lower() in AI_DENYLIST:
#                 return False
#         return True
#     return False

# def has_allowed_agi_form(txt: str) -> bool:
#     """Same logic as has_allowed_ai_form but for AGI."""
#     if _RE_AGI_ALLOWED.search(txt):
#         for tok in re.findall(r'[@#][A-Za-z0-9_-]+', txt):
#             if tok.lower() in AI_DENYLIST:  # in case of overlap
#                 return False
#         return True
#     return False

# def seems_english(text: str, min_ascii_chars: int = 5, min_ascii_share: float = 0.75) -> bool:
#     """
#     Relaxed heuristic: counts ASCII letters/digits/punctuation/spaces; ignores emojis & other Unicode.
#     Requires both a minimum count and share of ASCII among candidate characters.
#     """
#     if not text:
#         return False

#     ascii_pool = set(string.ascii_letters + string.digits + string.punctuation + " ")
#     candidates = [ch for ch in text if ch.isalnum() or ch in string.punctuation or ch.isspace()]
#     if not candidates:
#         return False

#     ascii_chars = sum(ch in ascii_pool for ch in candidates)
#     return ascii_chars >= min_ascii_chars and (ascii_chars / len(candidates) >= min_ascii_share)

# def keep_tweet(tw: dict) -> bool:
#     """
#     Keep a tweet if:
#       1) It matches a core keyword in `pattern` OR matches an allowed AI/AGI form (not in denylist); and
#       2) It's English (lang startswith 'en' OR passes heuristic).

#     ✅ Kept examples:
#         "I use ChatGPT daily"        -> keyword = ChatGPT
#         "AI-powered apps"            -> allowed AI hyphen form
#         "#AIart is trending"         -> allowed AI hashtag
#         "@AIResearch updates"        -> allowed AI mention
#         "AI is the future"           -> standalone AI
#         "AGI-safety paper"           -> allowed AGI hyphen form

#     ❌ Rejected examples:
#         "Brain again daily"          -> 'ai' inside other word, no keyword
#         "This trend shows aging..."  -> 'agi' inside other word, no keyword
#         "テスト GPT"                   -> non-English (fails heuristic/lang)
#         "#Airdrop event"             -> blocked by denylist
#         "@Airdrop promo"             -> blocked by denylist
#     """
#     txt = (tw.get("text") or "").strip()
#     if not txt:
#         return False

#     # 1) Must match any core keyword OR allowed AI/AGI form (with denylist check)
#     if not (pattern.search(txt) or has_allowed_ai_form(txt) or has_allowed_agi_form(txt)):
#         return False

#     # 2) English check
#     lang = (tw.get("lang") or "").lower()
#     if not (lang.startswith("en") or seems_english(txt)):
#         return False

#     return True

# %%
# --- Core keywords (NO bare AI/AGI here) ------------------------------------
# We exclude bare "AI"/"AGI" because they're too permissive ("daily", "aging").
# Instead, we handle them explicitly with _RE_AI_ALLOWED/_RE_AGI_ALLOWED below.
pattern = re.compile(
    r'(?:'                                 # group of alternatives
        r'\bChatGPT\b|'
        r'\bChat-GPT\b|'
        r'\bGPT(?:-?3|-?4)?\b|'            # GPT, GPT3, GPT-3, GPT4, GPT-4
        r'\bLLMs?\b|'                      # LLM, LLMs
        r'\bBARD\b|'
        r'\bBERT\b|'
        r'\bLaMDA\b|'
        r'\bLLaMA\b|'
        r'\bMed-PaLM\b|'
        r'Bing AI|'                        # phrase
        r'artificial intelligence|'        # phrase
        r'large language models'           # phrase
    r')',
    re.IGNORECASE
)

# --- Allowed AI/AGI forms ----------------------------------------------------
# ✅ Allowed (examples):
#   AI / #AI / #AIart / @AI_news / AI-powered
#   AGI / #AGI / #AGI-safety / @AGIteam / AGI-related
#
# ❌ Rejected:
#   "again", "brain", "aging", "engaging" (embedded 'ai'/'agi' inside words)
# Exclude 'ai' preceded by an apostrophe (e.g., j'ai, l'ai)
_RE_AI_ALLOWED  = re.compile(r'(?:(?<![\'])?\bAI\b|#AI[\w-]*|@AI[\w-]*|AI-[A-Za-z])',   re.IGNORECASE)
_RE_AGI_ALLOWED = re.compile(r'(?:\bAGI\b|#AGI[\w-]*|@AGI[\w-]*|AGI-[A-Za-z])', re.IGNORECASE)

# --- Denylist for spammy tokens ----------------------------------------------
# These strings look like allowed forms but are NOT genuine AI/AGI keywords.
# Example: "#Airdrop" matches "#AI…" but should be rejected.
# block "#airdrop", "#airdrops", "#airdrop2025", "@airdrop_io", etc.
_AI_DENYLIST_RE = re.compile(r'(?i)^(?:#|@)airdrop\w*$')


def has_allowed_ai_form(txt: str) -> bool:
    """
    Returns True if the text contains an allowed AI form
    (standalone, hashtag, mention, hyphen), but not if it's in the denylist.
    """
    if _RE_AI_ALLOWED.search(txt):
        for tok in re.findall(r'[@#][A-Za-z0-9_-]+', txt):
            if _AI_DENYLIST_RE.search(tok):
                return False
        return True
    return False

def has_allowed_agi_form(txt: str) -> bool:
    """Same logic as has_allowed_ai_form but for AGI."""
    if _RE_AGI_ALLOWED.search(txt):
        for tok in re.findall(r'[@#][A-Za-z0-9_-]+', txt):
            if _AI_DENYLIST_RE.search(tok):  # in case of overlap
                return False
        return True
    return False

# --- Minimal ES/FR/PT stopword sets (keep short, high-signal) ---------------
STOPWORDS_ES = {
    "gracias","por","para","porque","tambien","también","hola","adios","adiós",
    "buenos","buenas","dias","días","noche","noches","hoy","mañana","ayer",
    "todos","todas","todo","toda","usted","ustedes","nosotros","vosotros",
    "pero","aunque","si","sí","cada","desde","hasta","segun","según","sobre",
    "entre","sin","con","como","cuando","cuándo","donde","dónde","que","qué",
    "del","al","una","uno","unas","unos","este","esta","estas","estos","eso",
}
STOPWORDS_FR = {
    "merci","bonjour","bonsoir","salut","oui","non","pourquoi","parce","que",
    "cest","c'était","c’etait","c'etait","ça","ca","très","tres",
    "je","tu","il","elle","nous","vous","ils","elles",
    "de","du","des","la","le","les","un","une","au","aux","avec","sans","sur","sous",
    "comme","quand","où","ou","pour","entre","depuis","jusqu","chez",
}
STOPWORDS_PT = {
    "ola","olá","oi","obrigado","obrigada","por","para","porque","tambem","também",
    "de","do","da","dos","das","no","na","nos","nas","um","uma","uns","umas",
    "e","ou","mas","como","quando","onde","que","quê","qual","quais",
    "eu","tu","ele","ela","nos","nós","vos","vós","eles","elas","você","vocês",
    "sei","não","nao","sim","muito","pouco","mais","menos","aqui","ali","lá","la",
    "essas","esses","este","esta","isso","aquilo","tudo","nada","sempre","nunca",
}
STOPWORDS_NON_EN = STOPWORDS_ES | STOPWORDS_FR | STOPWORDS_PT

# precompiled token pattern (includes accented letters)
_TOKEN_RE = re.compile(r"[A-Za-zÀ-ÿ']+")

# --- Optional langdetect -----------------------------------------------------
def _try_langdetect_is_english(text: str, min_prob: float = 0.85):
    """
    Best-effort language ID using langdetect if available.
    Returns True/False on confident EN/non-EN, or None if unknown/unavailable/low-confidence.
    """
    try:
        import langdetect
        from langdetect import detect_langs
        # Optional: make deterministic
        # langdetect.DetectorFactory.seed = 0
        preds = detect_langs(text)
        if not preds:
            return None
        top = max(preds, key=lambda p: p.prob)
        if top.prob >= min_prob:
            return (top.lang == "en")
        return None
    except Exception:
        return None

def seems_english(
    text: str,
    *,
    # ASCII/diacritics heuristic
    min_ascii_chars: int = 5,
    min_ascii_share: float = 0.75,
    max_accented_share: float = 0.06,      # tighten to 0.04–0.05 to be stricter
    # Tweet-length strategy
    short_text_len: int = 40,              # <40 chars => treat as "short"
    # Stopword thresholds (long texts)
    non_en_stopword_min_hits: int = 2,
    non_en_stopword_min_ratio: float = 0.30,
    # Stopword thresholds (short texts) — stricter to catch brief FR/ES/PT
    short_stopword_min_hits: int = 1,
    short_stopword_min_ratio: float = 0.25,
    # langdetect thresholds for long texts
    use_langdetect: bool = True,
    langdetect_min_prob: float = 0.85,
) -> bool:
    """
    English-likeness heuristic with a split strategy:

    SHORT tweets (len(text) < short_text_len):
      • Skip langdetect (noisy on very short text).
      • Use ASCII/diacritics heuristic.
      • Use FR/ES/PT stopword screen with stricter thresholds
        (short_stopword_min_hits / short_stopword_min_ratio).

    LONGER tweets (len(text) >= short_text_len):
      • Try langdetect first:
          - Confident EN (>= langdetect_min_prob)  -> accept
          - Confident non‑EN                       -> reject
          - Otherwise                              -> fall through
      • Then ASCII/diacritics heuristic.
      • Then FR/ES/PT stopword screen with normal thresholds
        (non_en_stopword_min_hits / non_en_stopword_min_ratio).
    """
    if not text:
        return False

    # Clean text by removing URLs, mentions, and hashtags
    txt_clean = re.sub(r'https?://\S+|[@#]\w+', '', text)

    is_short = len(txt_clean) < short_text_len

    # --- ASCII coverage & diacritics (used in both paths) ---
    ascii_pool = set(string.ascii_letters + string.digits + string.punctuation + " ")
    candidates = [ch for ch in txt_clean if ch.isalnum() or ch in string.punctuation or ch.isspace()]
    if not candidates:
        return False
    ascii_chars = sum(ch in ascii_pool for ch in candidates)
    ascii_ratio = ascii_chars / len(candidates)
    if ascii_chars < min_ascii_chars or ascii_ratio < min_ascii_share:
        return False

    letters = [ch for ch in txt_clean if ch.isalpha()]
    if letters:
        accented_letters = sum(127 < ord(ch) <= 255 for ch in letters)
        accented_ratio = accented_letters / len(letters)
        if accented_ratio > max_accented_share:
            return False

    # --- Branch: short vs long ---
    if is_short:
        # SHORT: rely on stopwords (stricter) after ASCII/diacritics passed
        tokens = [t.lower() for t in _TOKEN_RE.findall(txt_clean)]
        if tokens:
            hits = sum(t in STOPWORDS_NON_EN for t in tokens)
            hit_ratio = hits / len(tokens)
            if hits >= short_stopword_min_hits and hit_ratio >= short_stopword_min_ratio:
                return False
        return True
    else:
        # LONG: try langdetect first (if enabled)
        if use_langdetect:
            is_en = _try_langdetect_is_english(txt_clean, min_prob=langdetect_min_prob)
            if is_en is True:
                return True
            if is_en is False:
                return False
            # None -> fall through

        # Then stopword screen (normal thresholds)
        tokens = [t.lower() for t in _TOKEN_RE.findall(txt_clean)]
        if tokens:
            hits = sum(t in STOPWORDS_NON_EN for t in tokens)
            hit_ratio = hits / len(tokens)
            if hits >= non_en_stopword_min_hits and hit_ratio >= non_en_stopword_min_ratio:
                return False
        return True

def keep_tweet(tw: dict) -> bool:
    """
    Keep a tweet if:
      1) It matches a core keyword in `pattern` OR matches an allowed AI/AGI form (not in denylist); and
      2) It's English (lang startswith 'en' OR passes heuristic).

    ✅ Kept examples:
        "I use ChatGPT daily"        -> keyword = ChatGPT
        "AI-powered apps"            -> allowed AI hyphen form
        "#AIart is trending"         -> allowed AI hashtag
        "@AIResearch updates"        -> allowed AI mention
        "AI is the future"           -> standalone AI
        "AGI-safety paper"           -> allowed AGI hyphen form

    ❌ Rejected examples:
        "Brain again daily"          -> 'ai' inside other word, no keyword
        "This trend shows aging..."  -> 'agi' inside other word, no keyword
        "テスト GPT"                   -> non-English (fails heuristic/lang)
        "#Airdrop event"             -> blocked by denylist
        "@Airdrop promo"             -> blocked by denylist
    """
    txt = (tw.get("text") or "").strip()
    if not txt:
        return False

    # 1) Must contain one of the keywords OR an allowed AI/AGI form (with denylist check)
    if not (pattern.search(txt) or has_allowed_ai_form(txt) or has_allowed_agi_form(txt)):
        return False

    # 2) English check
    lang = (tw.get("lang") or "").lower()
    if not (lang.startswith("en") or seems_english(txt)):
        return False

    return True

# %%
# We only consider tweets after September 2022
# Offset-aware datetime
earliest_date = datetime(2022, 10, 31, tzinfo=timezone.utc)
earliest_date = earliest_date.date()

# Preprocessing
def preprocess(text):
    text = text.lower()
    text = re.sub(r'http\S+', 'http', text)
    text = re.sub(r'@\w+', '@user', text)
    text = re.sub(r'#(\w+)', r'\1', text)
    text = text.replace('\n', ' ')
    return text.strip()

# %%
def _safe_int(x, default=0):
    try:
        return int(x)
    except Exception:
        return default

def top_k_original_to_csv(input_path, output_path, k=100):
    """
    Reads a JSONL file of tweets, selects the top-k original tweets by retweets,
    and writes them into a CSV at output_path.
    CSV columns: text, retweets, type
    """
    input_path = Path(input_path)
    output_path = Path(output_path)

    heap = []                # min-heap of (retweets, tie_breaker, compact_tweet)
    _counter = itertools.count()
    ids_in_heap = set()      # prevent duplicates by tweet id

    bad_lines = 0
    print('Counting total tweets in file...')
    with input_path.open("r", encoding="utf-8") as f:
      total = sum(1 for _ in f)

    with input_path.open("r", encoding="utf-8") as f:
        for line in tqdm.tqdm(f, total=total, desc="Scanning tweets"):
            s = line.strip()
            if not s:
                continue
            try:
                tw = json.loads(s)
            except Exception:
                bad_lines += 1
                continue

            # Keep ONLY originals
            if (tw.get("type") or "").lower() != "original":
                continue

            tw_id = tw.get("id")
            if tw_id is None or tw_id in ids_in_heap:
                continue

            pm = tw.get("public_metrics") or {}
            rt = _safe_int(pm.get("retweets", pm.get("retweet_count", 0)), 0)

            compact = {
                "text": tw.get("text"),
                "retweets": rt,
                "type": "original",
            }

            item = (rt, next(_counter), compact)
            if len(heap) < k:
                heapq.heappush(heap, item)
                ids_in_heap.add(tw_id)
            else:
                if rt > heap[0][0]:
                    popped = heapq.heapreplace(heap, item)
                    popped_id = popped[2].get("id")
                    if popped_id in ids_in_heap:
                        ids_in_heap.remove(popped_id)
                    ids_in_heap.add(tw_id)

    # Sort by retweets descending
    top_sorted = sorted(heap, key=lambda x: x[0], reverse=True)
    top_records = [entry for _, _, entry in top_sorted]

    # Write to CSV
    with output_path.open("w", newline="", encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=["text", "retweets", "type"])
        writer.writeheader()
        writer.writerows(top_records)

    if bad_lines:
        print(f"Skipped {bad_lines} malformed lines.")

    print(f"✅ Wrote top {len(top_records)} tweets to {output_path}")

    return top_records

# %% [markdown]
# ## Prune Test DS

# %%
# Check how it looks, LINE BY LINE
do_prune = True
if do_prune:
    total_processed = 0
    duplicates_skipped = 0
    seen_all_ids = set()      # all IDs encountered
    seen_written = set()      # IDs actually written to the pruned file

    with open(cleanedds_folder/'AItrust_twits_dict_test.json','r',encoding='utf-8') as in_f, \
         open(cleanedds_folder/'AItrust_pruned_twits_test.json','w',encoding='utf-8') as out_f:

        for line in tqdm.tqdm(in_f, total=233094):
            try:
                twit = json.loads(line)
                twid = twit.get('id')
                if twid is None:
                    continue

                # track all ids seen
                seen_all_ids.add(twid)

                # ensure no duplicate IDs in the OUTPUT
                if twid in seen_written:
                    duplicates_skipped += 1
                    continue

                if keep_tweet(twit):
                    # parse date and filter by earliest_date
                    tw_date = twit['created_at']
                    date_string = tw_date.replace('Z', '+00:00')
                    date_only = datetime.fromisoformat(date_string).date()
                    if date_only >= earliest_date:
                        # enrich + write once
                        twit['processed_text'] = preprocess(twit['text'])
                        out_f.write(json.dumps(twit, ensure_ascii=False) + '\n')
                        seen_written.add(twid)
                        total_processed += 1

            except Exception as e:
                print(e)
                continue  # goes to the next iteration

    print('\nwritten:', total_processed)
    print('\nunique_ids_seen:', len(seen_all_ids))
    print('\nunique_ids_written:', len(seen_written))
    print('\nduplicates_skipped:', duplicates_skipped)
# Out:
# 100%|██████████| 233094/233094 [00:13<00:00, 17168.71it/s]
# written: 881
#
# unique_ids_seen: 1459
#
# unique_ids_written: 881
#
# duplicates_skipped: 129431

# %%
with open(cleanedds_folder/'AItrust_pruned_twits_test.json','r',encoding='utf-8') as f:
  i = 0
  twids = set()
  for line in tqdm.tqdm(f):
    twit = json.loads(line)
    twid = twit['id']
    twids.add(twid)
    # print(twit['text'])
    # print('-----')
    # print(twit['processed_text'])
    # print('-----')
    # print('-----')
    # print('\n')
    i+=1
    # if i>25:
    #   break
  print(i)
  print(len(twids))
# Out:
# 881it [00:00, 45074.19it/s]
# 881
# 881

# %%
input_path = cleanedds_folder/'AItrust_pruned_twits_test.json'
output_path = cleanedds_folder/"top_test_tweets.csv"
top_k_original_to_csv(input_path, output_path,100)
# Out:
# Counting total tweets in file...
# Scanning tweets: 100%|██████████| 881/881 [00:00<00:00, 53113.82it/s]
# ✅ Wrote top 100 tweets to /content/drive/My Drive/AI Public Trust/Data Sets/Cleaned Data/top_test_tweets.csv
# [{'text': 'Say no to AI generated art in the exhibitors and artist alley sections of conventions https://t.co/cIvsCRh7nP',
#   'retweets': 21001,
#   'type': 'original'},
#  {'text': 'Can we please stop calling it "AI art" and start calling it "AI generated images" instead? Art requires meaning and intention, AI has none of that',
#   'retweets': 7143,
#   'type': 'original'},
#  {'text': '“ai art makes art more accessible for disabled artists” so stealing and mismatching other ppl’s art is now considered accessibility?',
#   'retweets': 3433,
#   'type': 'original'},
#  {'text': 'Stop wasting time and money on tasks that AI can be doing instead. \n\nThese 7 free AI tools will help you stay on top of the game:',
#   'retweets': 3027,
#   'type': 'original'},
#  {'text': '8 AI tools that will save you hours of work:',
#   'retweets': 2829,
#   'type': 'original'},
#  {'text': '🚨🇨🇳China: A Tesla malfunctions and runs off at Maximum speed instead of parking itself, killing 2 people and injuring several others. It is believed that its AI was sabotaged by Chinese engineers. https://t.co/uBuAS87vps',
#   'retweets': 2821,
#   'type': 'original'},
#  {'text': 'We are now officially #Live on #Opensea ! Big thank you to the whole team, including our digital artists, developers, AI technologists, community moderators and all the team leads. Great work, and see you in the #Metaverse https://t.co/pbxp3WgzTB',
#   'retweets': 2745,
#   'type': 'original'},
#  {'text': '“The Tesla Autopilot AI team, it’s about 150 engineers, and they’re outperforming teams that they’re competing against that are 3,000 engineers.” - @elonmusk https://t.co/bLApxEGru1',
#   'retweets': 2383,
#   'type': 'original'},
#  {'text': "🎉 @OctoPrint3D's newest FREE and UNLIMITED AI Spaghetti Detection is HERE!\n\nCelebrate With Us!\n👉Claim your FREE 30 DAYS of Supporter Perks\n👉Enter to win Supporter Perks FOR LIFE\n👉Enter to win a @Prusa3D i3 MK3S+\n\nEnable Gadget and enter to win NOW! 👇\nhttps://t.co/CuyQ7EoCpC https://t.co/qlvq7yfNDc",
#   'retweets': 2228,
#   'type': 'original'},
#  {'text': 'UK - Why has the UK Government allowed the WEF to write the principles for Ai procurement for the government? \n\nWhen did the WEF become a government department? https://t.co/B10XSK3ytg',
#   'retweets': 2106,
#   'type': 'original'},
#  {'text': 'From #KinKiKids\' 2003 Double A-side 17th single "Kokoro ni Yume o Kimi niwa Ai o," now available on YouTube with its unforgettable action-packed theatrical music video!\n\n🎵Stream it here!\nhttps://t.co/oj7bu434B7\n#YourJohnnysMusic https://t.co/Sc2qgnAPqx',
#   'retweets': 1710,
#   'type': 'original'},
#  {'text': '$MIT is live NOW on @latokens ! Buy $MIT TODAY!🔥\n#cryptotrader #trader #mit #mimeta #latoken #cryptocurrency #metaversedecisiontoken #decisionmaking #blockchain #ai #cryptostar #communityengagement #communitybuilding #audit #novos #kyc #cryptoexchange #exchange #nft #metaverse https://t.co/qjShKzmNHB',
#   'retweets': 1029,
#   'type': 'original'},
#  {'text': 'Stanford University is offering FREE online courses.\n\nNo need for an application or fee. \n\nLearn Computer Science to Artificial Intelligence for FREE\n\nA Thread 🧵👇',
#   'retweets': 978,
#   'type': 'original'},
#  {'text': "In 2023, my goal is to do more building than talking. I feel I've failed at this. I'll still do podcasts, but I want to spend most of my time on AI &amp; engineering efforts, with an existing team or a new one, building systems that try to increase the amount of love in the world.",
#   'retweets': 789,
#   'type': 'original'},
#  {'text': 'The Japanese words koi (恋) and ai (愛) both translate to Love in English, but there is a difference between them. Koi means to genuinely like someone just like first love, while Ai means unconditional love, eternal love. It’s the concept of love.',
#   'retweets': 620,
#   'type': 'original'},
#  {'text': "It's Backkk!\n\nBattle Prompts\nInter-Community Edition\n\n1) Visualize your ultimate fighter using\n@midjourney and enter arena\n\n2) PvP battles decided by GPT-3\n\n📣 Calling all communities requesting spots for beta test... teams slots on the line!\n\nRules &amp; Details Below ⬇️ https://t.co/SKsNZ5EQdo",
#   'retweets': 544,
#   'type': 'original'},
#  {'text': 'that mistranslation of describing nameless bard as a young boy has done irreversible damage… he was the head of a revolution in a war he was not 15',
#   'retweets': 385,
#   'type': 'original'},
#  {'text': 'Stop waiting time and use these tools instead:\n\nCanva ➟ Content Creation\nMonday ➟ Email Marketing\nPlanoly ➟ Planning &amp; Scheduling\nAi Copy ➟ Heading &amp; Copy Ideas\nAll HashtagAi ➟ Top Hashtags for You',
#   'retweets': 369,
#   'type': 'original'},
#  {'text': 'op: please say something heart fluttering\nyuta: 😗? wo...wo ai ni (i love you)\n\n🫠\n https://t.co/60N9j7wNl9',
#   'retweets': 336,
#   'type': 'original'},
#  {'text': 'so i was fooling around with ai and it gave me a pretty pic and i decided to "fix" it a bit? idk i just think it looks kinda nice, and it was something relaxing to do?... https://t.co/DLC5p0iOs2',
#   'retweets': 295,
#   'type': 'original'},
#  {'text': 'AI will eliminate the job you currently have.',
#   'retweets': 289,
#   'type': 'original'},
#  {'text': 'As one of the players, this is accurate\n⚔️🎲\ncredit: GlennCap\n#dnd  #rpg  #dndmemes  #tabletopgames #cosplay  #follow  #bard https://t.co/rX9D9MfKxe',
#   'retweets': 288,
#   'type': 'original'},
#  {'text': 'ok so first we got instagram algorithm giving us literally nothing, twitter is on fire, and now deviant art with the AI stuff? why can’t artists just have One stable platform please i am begging',
#   'retweets': 276,
#   'type': 'original'},
#  {'text': 'One more. Based on AI, liked the colors of this one. https://t.co/A32yJlh9Qd',
#   'retweets': 244,
#   'type': 'original'},
#  {'text': '💥🤖What are the🔝#Application of #DeepLearning❓\n\nv/@ValueCoders \n#MachineLearning #AI #DataScience #Analytics #Data #fintech #Business #Robot #Digital #tech #technology #innovation #Flutter #twitme #coding #100DaysOfCode #python #javascript #marketing #blockchain #IoT #CES2023 https://t.co/TRqMYNm8y8',
#   'retweets': 236,
#   'type': 'original'},
#  {'text': "DenFur would like to announce a policy update for our Dealers &amp; Artists:\n\nGoing forward, the sale of AI generated art, art with AI generated elements, or merchandise produced from AI generated art is prohibited in the Dealer's Den, Artist Alley, &amp; Art Show of AEIOU's conventions.",
#   'retweets': 234,
#   'type': 'original'},
#  {'text': "Screw it, we're playing text only\n🧙🏻\u200d♂️⚔️🐉\nfrom: tomeofsummoning\n#dungeonsanddragons #rpg  #dndcharacter  #tabletopgames #criticalrole  #meme #bard https://t.co/ot6MTxLgSI",
#   'retweets': 232,
#   'type': 'original'},
#  {'text': 'yo @Excision i rendered out some AI art stage designs for Lost Lands 2023 😂🦖 https://t.co/vPMkBr4Pnf',
#   'retweets': 232,
#   'type': 'original'},
#  {'text': 'Computational Linear Algebra for Coders - FAST DOT AI\n\nA great maths course taught with  "top-down approach", much like Practical DL for Coders. Taught in Python, uses basic libraries(NumPy, Scikit-Learn) &amp; PyTorch.\n\nVideos: https://t.co/OfbLvpXunR\n\nCode: https://t.co/R41oTZPSZD https://t.co/oyDqaWU7b7',
#   'retweets': 231,
#   'type': 'original'},
#  {'text': '🌱art share for #TransAwarenessWeek !\n\ntrans artists, introduce urself, drop ur art (+ ur c0mmissi0ns, if u\'d like), and support other artists in the thread !\n\ncis ppl please rt\nI will be rt\'ing throughout the day\n\nno NSFW, no N//F//Ts, no AI "art"\n\n#artshare #arttwt',
#   'retweets': 216,
#   'type': 'original'},
#  {'text': 'Let’s go down the logic hole of people who see nothing wrong with AI Art. https://t.co/z1OlUJqSWY',
#   'retweets': 212,
#   'type': 'original'},
#  {'text': "My latest for @restofworld as part of @pulitzercenter's AI Accountability Fellowship: \n\nI write about how Indian gig workers—tired of obscure blackbox algorithms controlling their lives—are coming up with ways to game the system.\n\nhttps://t.co/KzKn8PHqeT",
#   'retweets': 206,
#   'type': 'original'},
#  {'text': 'I feel like somebody at FromSoftware is a big geology nerd. Glintstone Sorcerers are referred to as "PyroxeneMagician" in their AI, with pyroxenes being a real life mineral group. The most common pyroxene is apparently Augite, which may sound familiar to fans of Demon\'s Souls. https://t.co/qsLI2ciAEK',
#   'retweets': 206,
#   'type': 'original'},
#  {'text': 'Hey #nftcommunity i’m giving away 🔺\n\n#ava_ape #98 \n\nTo enter\n👇👇👇\n\n1️⃣ Follow @Babar0x and @ai_mutants \n2️⃣ Like, RT and tag 3 friend \n3️⃣ Use Avax related hashtags 🔺\n\n48 hours ⏱ \n\n#AVAX\u202f\u202f\u202f\xa0\xa0\xa0\xa0 #Avalanche\u202f\u202f\u202f\xa0\xa0\xa0\xa0 #AvaxNftRush #AvaxNFTSzn #NFTs #NFTGiveaway #FreeMint https://t.co/uHK5N7dsIy',
#   'retweets': 191,
#   'type': 'original'},
#  {'text': 'Artists!\n\nDrop your art below!\n\nNo n/f.ts or ai art 👿',
#   'retweets': 181,
#   'type': 'original'},
#  {'text': 'Powerful, inquisitive, and somewhat naive, Penny is an advanced AI with very humanlike qualities. She\'s best friends with Team RWBY and is considered the Protector of Mantle. Say "salutations!" when you meet her in RWBY: Arrowfell, launching tomorrow! https://t.co/3pVzavwhvb https://t.co/0I81iHjKJo',
#   'retweets': 176,
#   'type': 'original'},
#  {'text': '700-page PDF — #Algorithms for Decision-Making — download brilliant &amp; comprehensive FREE eBook from MIT: https://t.co/TRP1USGDrF\n—————\n#abdsc #AI #MachineLearning #BigData #DataScience #DataScientists #Mathematics #Statistics #DecisionScience #DataLeadership #AnalyticsStrategy https://t.co/kfbKqbIBO5',
#   'retweets': 171,
#   'type': 'original'},
#  {'text': 'Just a heads up to fellow tum drawers, seems like people are yoinking preggo art for ai prompts now. I saw this when I booted up dA. Like more than half of the front page is full of ai art now. @CaffeineCuts https://t.co/HdcIUF8cnU',
#   'retweets': 138,
#   'type': 'original'},
#  {'text': 'Tian: Leave me, i know everything. Rubbish/Scum like you, just do everything because of money, do for your own benefit.\nJiw: Tian, listen to me first\nTian: Go away, Ai Jiw, such a liar. Never let me see your face again\n\n#คุณชายEP13\n\nhttps://t.co/3w8pgSTdvp',
#   'retweets': 136,
#   'type': 'original'},
#  {'text': 'How robust is your risk management plan?\nHear from Bingqing Li, our AI Ecosystem Architect, Philippe Rolland, our Senior Director of Cloud Alliance AWS, &amp; Kris Skrinak, Global Machine Learning Segment Lead at @awscloud, in our webinar on 23 Nov 22. Sign up https://t.co/RVbbbqsNiM https://t.co/yQZocYihVQ',
#   'retweets': 122,
#   'type': 'original'},
#  {'text': "I understand why mainstream games have handhold mechanics like your AI yelling out puzzle answers. They gotta appeal to a lot of people and don't want any player getting stuck and giving up.\n\nBut please for the love of god make it a setting to turn that stuff OFF 💀",
#   'retweets': 122,
#   'type': 'original'},
#  {'text': '🛒What are the6⃣Latest E-commerce Trends❓ \n\nv/@techmenttech\n#ecommerce #Digital #AR #VR #BigData #technology #innovation #business #investing #AI #DataScience #Flutter #python #javascript #web3 #TensorFlow #NFT #marketing #100DaysofCode #coding #fintech #Robot #IoT #Womenintech https://t.co/mYeIlDNUtI',
#   'retweets': 117,
#   'type': 'original'},
#  {'text': "AI 'artists' do not deserve tables at cons. DO NOT BUY THEIR WORK. PUBLICALLY SHAME EVERY CON THAT LETS AN AI 'ARTIST' TABLE. Call them out. They're letting THEIVES PROFIT.",
#   'retweets': 116,
#   'type': 'original'},
#  {'text': 'We really looked at this man and collectively agreed that he is a soft-dom across every universe from pirate to professor to sentient AI https://t.co/6X7tDAQJV0',
#   'retweets': 113,
#   'type': 'original'},
#  {'text': "The Bloom paper is out. Looks like it's doing worse than current GPT3 API in zero-shot generation tasks in English but better than other open-source LLMs &amp; better than all in zs multi-lingual (which was the main goal). Proud of the work from the community! https://t.co/NMHIzi1F79 https://t.co/oiIjWqJseC",
#   'retweets': 113,
#   'type': 'original'},
#  {'text': 'Latest Innovative #5G &amp; 5.5G Use Cases in the Asia-Pacific Region\nby @Ronald_vanLoon &amp; Abel Deng |\n\n#HuaweiPartner #MBBF2022 #5GLeadstheStride #HWMBBF @Huawei @HuaweiWireless #AI #Cloud #Network #IoT #Robot #Metaverse #Innovation #Technology\n\nCc: @antgrasso @GlenGilmore https://t.co/SugDFUehax',
#   'retweets': 109,
#   'type': 'original'},
#  {'text': 'SQL Joins 👨\u200d💻\n\n#BigData #Analytics #DataScience #AI #MachineLearning #IoT #PyTorch #Python #RStats #TensorFlow #Java #JavaScript #ReactJS #React #Serverless #DataScientist #Linux #Programming #Coding #100DaysofCode #DevOps #SQL #Blockchain #CyberSecurity #Flutter #PHP #Github https://t.co/L1y1ic6lPo',
#   'retweets': 106,
#   'type': 'original'},
#  {'text': 'From @intel #Edge #AI Certification to 30 Day #developer Challenge! Explore ways to #learn how to optimise #Smart #technology &amp; an #IIoT #manufacturing case here⬇️\n\nhttps://t.co/G8aRdCRxcm \n\n#SmartNews #IntelPartner @insightdottech #IoT #data #Cloud #100DaysOfCode #ITInfluencer https://t.co/QwpekyLSlb',
#   'retweets': 105,
#   'type': 'original'},
#  {'text': 'Thank you for Cumming to my stream!\n\nai hentai https://t.co/s8tuTIjtOq',
#   'retweets': 99,
#   'type': 'original'},
#  {'text': '#aideku, dekussy, d/s, comm for anon, overstim, punishment, slight age-gap (dk 26 - ai 32), sadistic!aizawa, brat!deku\n\n"Shouta!!" A voice called out from outside the classroom, startling some. Everyone looked up when the door to their classroom was flung open.',
#   'retweets': 99,
#   'type': 'original'},
#  {'text': 'Learn about the new #Python Data #Analytics book by @wesmckinn here: https://t.co/1ZFlGCsOsk\n————\n#abdsc #DataScience #MachineLearning #BigData #AI #DataScientists #100DaysOfCode #Numpy #Pandas #Jupyter #DataWrangling\n———\n🌟👉The book: https://t.co/ZvAuOJXD4J https://t.co/LLue1cQolk',
#   'retweets': 95,
#   'type': 'original'},
#  {'text': "💜 ART SHARE 💜\n\nIt's been a while and I wanna see everyone's art! SFW only please! \n\n💜 Post your art in the replies!\n💜 RT this post!\n💜 Like/RT/Comment on your favorites!\n\n🚫 Dont drop and go! No nf/ts, no AI\n\nI'll RT replies throughout the day 💕 https://t.co/o4o7dVlM78",
#   'retweets': 95,
#   'type': 'original'},
#  {'text': 'Chrissmus a come mi waa mi llama https://t.co/ru2kUNbyGd',
#   'retweets': 93,
#   'type': 'original'},
#  {'text': 'Ever wonder how long we have been using these?\n\n#AI #blockchain #DigitalTransformation #Python #Cloud #BigData #5G #MachineLearning #reddit #WomenInSTEM #fintech #technology #100DaysOfCode #IoT #dataScientist #Jobs #MarketingTwitter #creators #web3 #DataAnalytics #womenintech https://t.co/7CUiO5S4DO',
#   'retweets': 91,
#   'type': 'original'},
#  {'text': '✨Good morning friends! I am happy to show you my new collection “Creatures”, which is presented at the FND✨\n✨ Manifold contract, reserve 0,05 ETH✨\n🖤 Creatures - this AI collection is more about feeling than about a fairy tale🖤 https://t.co/LmfmsTZyXq',
#   'retweets': 89,
#   'type': 'original'},
#  {'text': 'Can AI just paint weights or do UVs or any of the boring stuff please?',
#   'retweets': 89,
#   'type': 'original'},
#  {'text': '#XANA #metaverse the New Story “XANADO”\nThe episode #1 “XANA Metaverse”\nHas been Updated!\n\nThe story revolves around a group of talented individuals who started creating a blockchain-based metaverse.\n\nCheck out!\nhttps://t.co/Klxt313Qa3\n\n#XANAGenesis #AI $XETA #Crypto',
#   'retweets': 77,
#   'type': 'original'},
#  {'text': "Let's do an #artshare !!\nLet's start the week discovering new art!\n\nIntroduce yourself and show us your art!\nI'm going to RT today\nNo AI https://t.co/OVE7chRjxW",
#   'retweets': 72,
#   'type': 'original'},
#  {'text': "frankenstein's monster (painting with AI) https://t.co/DeBuNyMPEZ",
#   'retweets': 70,
#   'type': 'original'},
#  {'text': 'Key #Python Packages for #DataScientists\nVia @ingliguori\n#MachineLearning #DataScience #SQL #Cybersecurity #BigData #Analytics #AI #IIoT #RStats #TensorFlow #JavaScript #ReactJS #CloudComputing #DataScientist #Linux #Programming #Coding #100DaysofCode #NodeJS #golang #NLP #GitHub https://t.co/GuTnvcr59R',
#   'retweets': 68,
#   'type': 'original'},
#  {'text': 'Yes, Ben Franklin is a fiduciary wealth manager, but a cool one that do your annual planning review in a coffee shop.\n\n"Photographer Uses AI to Imagine What Historical Icons Would Look Like Today" https://t.co/eXIz75t4oc https://t.co/o1a5HCl4q9',
#   'retweets': 66,
#   'type': 'original'},
#  {'text': 'Apparently Rush Duels have alternate artwork cards drawn by the anime seiyus, so here is a sick version of “Makiu, the Magical Mist” that Fairouz Ai drew herself. https://t.co/lF4jQOiCeO',
#   'retweets': 64,
#   'type': 'original'},
#  {'text': 'Side eye\n#stablediffusion #StableDiffusionWaifu #WaifuDiffusion #AIArtwork https://t.co/fxWslzEaiI',
#   'retweets': 63,
#   'type': 'original'},
#  {'text': '🖌️Super Mario Odyssey Concept🖌️\nUpscaled by AI and restored in Photoshop. \nHope you like it! \n#retrogaming #SuperMario #gameart https://t.co/20lLxGRdZ9',
#   'retweets': 62,
#   'type': 'original'},
#  {'text': '(Kinda rushed old work) He was hungry so it was worth to try some llama milk \n\nI swear if I’ll ever finish all the works I’ve done before but maybe not all of them, I’ll do some John the llama stuff \n\n#NSFWFortnite #baransfw #nsfwartwork https://t.co/qTLz56cIKA',
#   'retweets': 60,
#   'type': 'original'},
#  {'text': 'Sometimes AI is really bad with hands, and sometimes it almost gets them right :P https://t.co/7EDQIVO436',
#   'retweets': 58,
#   'type': 'original'},
#  {'text': 'Future of marine #Robotics\nby @Quicktake\n\n#AI #MachineLearning #ArtificialIntelligence #ML #Innovation #Autonomous #TechForGood #FutureOfWork\n\ncc: @ronald_vanloon @pbalakrishnarao @levie @meisshaily https://t.co/nncdxt0u7o',
#   'retweets': 56,
#   'type': 'original'},
#  {'text': 'Top Strategic Technology Trends 2023\n\n#MachineLearning #AI #Python #DataScience #BigData\n#Algorithms #IoT #100DaysOfMLCode #5G #robots  #4IR #technology \n#ArtificialIntelligence #NLP #cloud #Industry40 #cybersecurity https://t.co/i5I33q8htQ',
#   'retweets': 56,
#   'type': 'original'},
#  {'text': 'Hey degen fam i’m Giving away 🔺\n\nx1 Ava Ape Nft 1St Ape Ai Project\n\nTo enter\n👇👇👇\n\n1️⃣ Follow @Babar0x and @ai_mutants \n\n2️⃣ Like, RT and tag 3 friend \n\n3️⃣ Use Avax related hashtags 🔺\n\n48 hours ⏱ \n\n#AVAX\xa0\xa0\xa0\xa0 #Avalanche\xa0\xa0\xa0\xa0 #AvaxNftRush #AvaxNFTSzn #NFTs #NFTGiveaway #FreeMint https://t.co/4OIzzVnKE4',
#   'retweets': 52,
#   'type': 'original'},
#  {'text': '🌟💯🚀Popular #MachineLearning Algorithms Explained With #Python Code: https://t.co/xc67ZU8pYt by @TheInsaneApp\n————\n#BigData #DataScience #AI #Statistics #ML #100DaysOfCode #DeepLearning #DataScientists #Coding #NeuralNetworks https://t.co/IHNUTwe6PX',
#   'retweets': 52,
#   'type': 'original'},
#  {'text': 'Nihilists after getting a slimy handjop from the AI girl wearing a penguin parka https://t.co/STc24Kwaqz',
#   'retweets': 47,
#   'type': 'original'},
#  {'text': 'This is a form of AI humor.\n\nBy War and Peas, Source: https://t.co/4jHe23palZ https://t.co/g9jslKrxkK',
#   'retweets': 44,
#   'type': 'original'},
#  {'text': 'Chinese researchers created a Cyborg pigeon.🤖 \n\nWatch until the end!\n\n#Data #DataScience #programming #DataScientist #AI #robots #MachineLearning #TensorFlow #coding #100DaysOfCode #fintech #BigData #IoT #robotics #automation #technology #robotsystems #artificialintelligence https://t.co/BUEsnrJjR8',
#   'retweets': 44,
#   'type': 'original'},
#  {'text': '#DigiLocker has #successfully completed second-level #Integration with #Ayushman #Bharat #Digital #Mission\nUtilize #DigiLocker as Personal #Health Records #APP #DigitalIndia\n#DigitalTransformation\n#DiGiTALhealth\n#DigitalMarketing\n#healthcare\n#HealthForAll\n#HealthInclusivity\n#AI https://t.co/Oq83q1Cg3k',
#   'retweets': 42,
#   'type': 'original'},
#  {'text': 'It\'s kind of disheartening to hear supposedly #AI researchers going "Yeah, I know #LLM\'s are trained to predict the next word, but I kinda think may be they are intelligent agents.." \n\nYou kind of begin to understand why alchemy survived so damn long..',
#   'retweets': 42,
#   'type': 'original'},
#  {'text': 'Monday OC #artshare? You bet! Show me some of your BBs! \nExtra credit: tell us their most prized possession\n(no n/sfw, n/ft, or ai art) https://t.co/NGQlKMba4h',
#   'retweets': 41,
#   'type': 'original'},
#  {'text': 'The 60th #Top500 list is officially released at #SC22\n\n@ORNL’s Exaflop machine #Frontier keeps top spot, new competitor Leonardo breaks the Top10 \n\nhttps://t.co/pBiXgswOjC\n\n#HPC #AI https://t.co/c2ujH3RyB1',
#   'retweets': 40,
#   'type': 'original'},
#  {'text': 'My piece, "Milk" has been listed for auction with a starting price of just 0.15 $ETH, inspired by @a5ht4r, this is a wholly new piece outside of my comfort zone. Blended Photography. AI, and Photoshop; it comes with prose.\n\nhttps://t.co/QZRfEcBBNL https://t.co/hMcFNYTP8z',
#   'retweets': 36,
#   'type': 'original'},
#  {'text': "The technology that underlies NFTs can be thought of as a container.\n\nIsn't it time we fill these containers with something other than just JPEGs?\n\n @aiarena_crypto is embedding AI models into NFTs.\n\nIf you believe in AI, our progress will not only change gaming, but the world.",
#   'retweets': 35,
#   'type': 'original'},
#  {'text': 'What started as an #AI powered tool to train crisis counselors supporting LGBTQ+ youth, developed by @TrevorProject &amp; a #GoogleOrgFellowship team, will now be redeployed in collaboration with ReflexAI to serve the #Veteran community: https://t.co/yBlJM8BVyJ #VeteransDay https://t.co/bPabChq8kh',
#   'retweets': 32,
#   'type': 'original'},
#  {'text': 'Now this is so damn cute... 🥺🥺 \n\nWhen Nhai said, get out and \n\nAi said... Come here let me kiss you. \n\n😳☺🥹🥹🫠🫠😭😭 \n\n#AilongNhaiEP8 \n#MeenNicha8 #PingKrittanun \n#มีนปิง #MeenPing #อัยย์หลงไน๋ #AiLongNhaiTheSeries \n\nhttps://t.co/uWi8edI78e',
#   'retweets': 28,
#   'type': 'original'},
#  {'text': 'a few open questions/thoughts from taking off the rose-colored glasses on “generative AI": what disruptions are overblown, the perils of building start-ups (or features) on others’ models, and what will (and will never) change, in no particular order:',
#   'retweets': 28,
#   'type': 'original'},
#  {'text': 'Python for Everybody: Exploring Data in Python 3\n\nLink - https://t.co/jQDRMSQXqQ\n\n#Python #Python3 #100DaysOfCode #CodeNewbies #WomenWhoCode #DEVCommunity #DevOps #code #Coding #DataAnalytics #DataScience #MachineLearning #AI #SoftwareEngineer #programming',
#   'retweets': 26,
#   'type': 'original'},
#  {'text': 'Gm to those interested in AI ☀️ https://t.co/srKZrQtwfY',
#   'retweets': 25,
#   'type': 'original'},
#  {'text': "Offering *discounted* Full body art, rig + 3 simple exp's for $1,300. \n🎨@ai__bun\nAdditional expressions are fine but will add to the price. Attached is an example of Bun's art style; a rendered example too(not offering chibis at this time). Will delete tweet when taken.\n\n#Vtuber https://t.co/5jKoKx9C4J",
#   'retweets': 25,
#   'type': 'original'},
#  {'text': "I'm all in on LLMs.  Looking for a few research interns this summer to work closely w/me @drosen and @mdredze on exploring large language models. So much to explore!\n\nhttps://t.co/TYDRpSm8c8",
#   'retweets': 24,
#   'type': 'original'},
#  {'text': 'Nows your chance to take Advantage of the AI REVOLUTION\n\n$NEURALINK #Neuralink\n\nhttps://t.co/MpESdWgkjB\n\n#ERC #ELONMUSK #Crypto\n#RBXS #RBXSamurai  $rbxs\n #neuraflection #1000xGems #web3  #cryptonews #CMC  #blockchain #CG https://t.co/2CFk9kMENS',
#   'retweets': 23,
#   'type': 'original'},
#  {'text': 'AI will allow for marketing funds to be utilized towards new Technology that will give #Neuralink an advantage over the competition and continue to Grow both socially and financially in todays hyper Competitive atmosphere.\n\nhttps://t.co/cB4xxA1Xj7\n\n#1000xgem #cmc #RBXS $rbxs https://t.co/zePLuyOt55',
#   'retweets': 23,
#   'type': 'original'},
#  {'text': 'The NeuraLink mission will be to Develop and acquire AI that will help give us the social and financial Advantage in todays #crypto Market.\n\n$Neuralink\n#Neuralink\n\nhttps://t.co/MpESdWytxJ\n\n#RBXS #RBXSamurai  $rbxs\n #staking #1000xGem   #cryptonews #CMC #ERC  #web3 #blockchain #CG https://t.co/dSv0nF6DSU',
#   'retweets': 23,
#   'type': 'original'},
#  {'text': 'there is so much worth focusing on outside of stupid FTX trash—gen art, desci, ai, social / communities + more. move on and focus on these new incentive and community models, so bored by the noise',
#   'retweets': 23,
#   'type': 'original'},
#  {'text': "How does Amazon leverage Robotics and AI in production in Fulfillment? I gave a Distinguished Seminar at Carnegie Mellon University detailing our work. Check out the entire talk video here:\n\nhttps://t.co/89ibP46uds\n\nHere's a summary 🧵.\n(1/n)",
#   'retweets': 22,
#   'type': 'original'},
#  {'text': 'Seeing Red is a visionary collection of #poetry that looks to our destiny and basks in the wonders of endless possibility. Experience this poignant selection of prose and imaginative imagery now. https://t.co/fPL261NoMT  \n#technology  \n#readers \n#poetry #AI\n#energy \n#booktwt https://t.co/7u2k7PvMav',
#   'retweets': 22,
#   'type': 'original'},
#  {'text': 'Virtual environments open new advertising opportunities! (Part 1) 🤩👏🏻\n\n#VR #AR #Cloud #BigData #Analytics #DataScience #AI #MachineLearning  #Python #Java  #ReactJS #React #CloudComputing #Serverless #DataScientist #Linux #Coding #100DaysofCode #DevOps #GitHub #SQL #Dev #Tech https://t.co/YuWXdm7LSk',
#   'retweets': 21,
#   'type': 'original'},
#  {'text': 'The #applications for this #innovative #AI are endless!  Kudos to #Cornell #University #researchers for this "cross-driving synthesis" #tech\n\n#ArtificialIntelligence #technology #innovation #research \n\n@EvanKirstel @Ronald_vanLoon @LindaGrass0 @Paula_Piccard @mvollmer1 https://t.co/RjPTb5KTob',
#   'retweets': 21,
#   'type': 'original'},
#  {'text': 'Did you miss $STARLINK, don’t miss this opportunity to grab $NEURALINK @ 250k MC  \n\nThe Future of AI Trading awaits\n🔥🔥\n #Neuralink\n🚀🚀\nhttps://t.co/MpESdWytxJ\n🤩🤩\n#RBXS #RBXSamurai $rbxs\n #neuraflection #1000xGem   #web3 #CMC #ERC #ELONMUSK #Cryptos #blockchain #staking https://t.co/CHlJNmPt8v',
#   'retweets': 21,
#   'type': 'original'},
#  {'text': '7 #MachineLearning Steps! 😊🙃😄\n\n#100DaysOfCode #5G #AI #Analytics #ArtificialIntelligence #BigData #Cloud #Coding #Data #DataScience #GitHub #IoT #JavaScript #Linux #ML #MLOps #NLP #NodeJS #OpenSource #Python #SQL #TScottClendaniel #WomenWhoCode https://t.co/PdbYkOohnC',
#   'retweets': 21,
#   'type': 'original'},
#  {'text': '[Free PDF Download] #MachineLearning for Absolute Beginners:  \n————\n#BigData #DataScience #AI #Algorithms #Mathematics #DataScientists  \n#artificialintelligence  #ml  #ai  #deeplearning  \n To follow posts: https://t.co/p81j7vPyp3 https://t.co/LC4T3njDuT',
#   'retweets': 20,
#   'type': 'original'},
#  {'text': 'Thread of Hugh Dancy/Will Graham images generated by AI  (stable diffusion) \n[some may have been edited by 喵狸喵气 on LOFTER] https://t.co/TdCtmjIytF',
#   'retweets': 20,
#   'type': 'original'},
#  {'text': 'I’ve already enjoyed @ComputerCrypto’s AI Birds SO much that I’ve decided to spread the joy! 😊 I’m going to Giveaway 1 per day this week to random people that interact 🫂 Say something nice about someone for a slight advantage 😉 \n#OneBirdOneVote 🦉 \n#Giveaway 🎁 https://t.co/Mnt5ZuKED1 https://t.co/OxiDWIq0Ew',
#   'retweets': 19,
#   'type': 'original'},
#  {'text': "Nhai taking revenge as Ping from P'Meen nt Ai...👀😂🤣😂🤣😂🤣  \n\n#MeenNicha8 #PingKrittanun \n#มีนปิง #MeenPing #อัยย์หลงไน๋ #AiLongNhaiTheSeries \n\nhttps://t.co/Xym1QxBf0n",
#   'retweets': 19,
#   'type': 'original'}]

# %% [markdown]
# ## Prune Full DS

# %%
# Check how it looks, LINE BY LINE
do_prune = False
if do_prune:
    total_processed = 0
    duplicates_skipped = 0
    seen_all_ids = set()      # all IDs encountered
    seen_written = set()      # IDs actually written to the pruned file

    with open(cleanedds_folder/'AItrust_twits_dict.json','r',encoding='utf-8') as in_f, \
         open(cleanedds_folder/'AItrust_pruned_twits.json','w',encoding='utf-8') as out_f:

        for line in tqdm.tqdm(in_f, total=36560405):
            try:
                twit = json.loads(line)
                twid = twit.get('id')
                if twid is None:
                    continue

                # track all ids seen
                seen_all_ids.add(twid)

                # ensure no duplicate IDs in the OUTPUT
                if twid in seen_written:
                    duplicates_skipped += 1
                    continue

                if keep_tweet(twit):
                    # parse date and filter by earliest_date
                    tw_date = twit['created_at']
                    date_string = tw_date.replace('Z', '+00:00')
                    date_only = datetime.fromisoformat(date_string).date()
                    if date_only >= earliest_date:
                        # enrich + write once
                        twit['processed_text'] = preprocess(twit['text'])
                        out_f.write(json.dumps(twit, ensure_ascii=False) + '\n')
                        seen_written.add(twid)
                        total_processed += 1

            except Exception as e:
                print(e)
                continue  # goes to the next iteration

    print('\nwritten:', total_processed)
    print('\nunique_ids_seen:', len(seen_all_ids))
    print('\nunique_ids_written:', len(seen_written))
    print('\nduplicates_skipped:', duplicates_skipped)

# %%
input_path = cleanedds_folder/'AItrust_pruned_twits.json'
output_path = cleanedds_folder/"top_pruned_tweets.csv"
top_k_original_to_csv(input_path, output_path,150)
# Out:
# Counting total tweets in file...
# Scanning tweets: 100%|██████████| 17410035/17410035 [05:53<00:00, 49233.23it/s]
# ✅ Wrote top 150 tweets to /content/drive/My Drive/AI Public Trust/Data Sets/Cleaned Data/top_pruned_tweets.csv
# [{'text': 'The damage done to the credibility of AI by ChatGPT engineers building in political bias is irreparable. https://t.co/s5fdoa8xQ6',
#   'retweets': 62463,
#   'type': 'original'},
#  {'text': 'Before I go to bed, I wanted to say this. I love the art community deeply. When AI artists steal/co-opt art from us I don’t just see art, I see people, mentors and friends. I don’t expect you to understand. \n#artcommunity #aiart https://t.co/5z77aqI3aK',
#   'retweets': 57647,
#   'type': 'original'},
#  {'text': "The listing we've been waiting for all this time is here: \n\n✅\xa0 Day 1: OKX — 16 Feb, 12:00 UTC\n\nhttps://t.co/cmgan0jAEJ\n\n✅\xa0 Day 2: Kucoin, Huobi, Gate, MEXC, Poloniex, Bitget\xa0 — 17 Feb, 12:00 UTC\n\nFasten your belts. $IGU is setting off on its journey.\n\n$IGU #AITOKEN #AI #LISTING https://t.co/4hxho3kY06",
#   'retweets': 37140,
#   'type': 'original'},
#  {'text': 'a YouTube comment about the way AI destroyed the field of translation years ago https://t.co/JoxLOkAHjP',
#   'retweets': 28015,
#   'type': 'original'},
#  {'text': 'miyazaki of studio ghibli, upon seeing an artificial intelligence presentation- "i strongly feel that this is an insult to life itself". https://t.co/UmOOWvsfjV',
#   'retweets': 27525,
#   'type': 'original'},
#  {'text': '🚨AI Rein Awakening - FREE MINT soon! 🚀\n\n🫡Popular JP artists’ AI-Human PFP NFT &amp; ex-SEGAer’ world-first Vampire-Survivor NFTgame. 👩\u200d🚀\n\n📖2023 updates - New PFP, GameFi, read: https://t.co/AXULV6LeVu\n\n🎁How to WL: https://t.co/IqjuwVydOd\n\n💎Premint WL - https://t.co/W4VnXVZlq5 https://t.co/936FWntw4a',
#   'retweets': 26628,
#   'type': 'original'},
#  {'text': "why artists don't like AI art, explained with the good ol' cake analogy https://t.co/iNFmFLIsI9",
#   'retweets': 26525,
#   'type': 'original'},
#  {'text': "We are thrilled to officially announce the addition of #AI IDOs to Seedify Launchpad after our community voted yes with a whopping 93.7% 🤖🚀\n\nPrepare for a new wave of cutting-edge AI projects 🔥\n\nAnd don't forget to get your $SFUND for the #IDOs 🚀\n\n#ArtificialIntelligence https://t.co/hVfqjj2t5u",
#   'retweets': 25442,
#   'type': 'original'},
#  {'text': 'Y’all was scared the vaccine had a microchip in it but paying to give your face to that AI app. Idk man',
#   'retweets': 24250,
#   'type': 'original'},
#  {'text': 'ChatGPT to the mainstream media https://t.co/gdqWTsHy14',
#   'retweets': 24176,
#   'type': 'original'},
#  {'text': '1/6 I created this image for everyone to use wherever they want. \nAi creates the “art” you see on the backs of artists being exploited. Ai “art” is currently scraping the web for art and uses it in datasets. No artist gave consent to have their art used. We were not compensated https://t.co/eGn352MyCj',
#   'retweets': 24001,
#   'type': 'original'},
#  {'text': 'The blockchain that distributes wealth of the AI Revolution to Billions of users.\n\nCryptoGPT: zkRollup Ethereum layer-2 for apps that push valuable data for the Artificial Intelligence boom\n\n&gt; 2+ mil end users at launch\n&gt; 100+ dev pipeline\n\nWeb: https://t.co/BL3zzEBmo7\n\nDetails👇 https://t.co/7au2pnxfEX',
#   'retweets': 22654,
#   'type': 'original'},
#  {'text': 'Say no to AI generated art in the exhibitors and artist alley sections of conventions https://t.co/cIvsCRh7nP',
#   'retweets': 21043,
#   'type': 'original'},
#  {'text': '🚀Claim AI NFT Marketplace on Sui: Pass Ticket!\n\nThen Get 500 XP on Crew3!\n\n✅This NFT ticket will give you early access to the first AI NFT marketplace on the Sui blockchain.\n\n🏆Claim here: https://t.co/qtnWM0AZoi\n\n#Sui #Galxe #NFTs https://t.co/siMkZYm96t',
#   'retweets': 20836,
#   'type': 'original'},
#  {'text': 'this is what ai voice generation is meant to be https://t.co/VASGmKasOU',
#   'retweets': 19930,
#   'type': 'original'},
#  {'text': "Leading the charge in AI and Web3 Gaming - we've made massive strides in partnerships, community, and our ecosystem. \n\nOur groundbreaking work in decentralized game publishing and cutting-edge AI are helping shape the future of the Metaverse. \n\n1/ Here's our 2022 #YearinReview 🧵 https://t.co/7N1d0et7ET",
#   'retweets': 18930,
#   'type': 'original'},
#  {'text': "On the topic of #AIart: a common defense for AI is that it learns from other art in the same way humans do, therefore it's not theft.\nSo I wanted to try to illustrate how that's not accurate. https://t.co/ozcJO3CNuF",
#   'retweets': 18694,
#   'type': 'original'},
#  {'text': 'I don’t get it. Why not focus on getting AI to perform more mundane tasks that don’t require creativity and nuance? Use it to free up time for actual human beings to focus more on the things they love? Pushing for it to write novels, make music, and create art is weird as hell.',
#   'retweets': 18425,
#   'type': 'original'},
#  {'text': 'bad news about that AI anime art generator https://t.co/sH34QzHB1M',
#   'retweets': 18379,
#   'type': 'original'},
#  {'text': 'today I woke up to the lovely news that an AI-generated comic lost its copyright protection because the USPTO determined that "copyrightable works require human authorship." \n\ngreat step in the right direction 👌 https://t.co/U1GGDwsPdC',
#   'retweets': 17128,
#   'type': 'original'},
#  {'text': 'Best AI Tools You Need To Know\n#chatgpt #chatgpt3 #ArtificialIntelligence #ai https://t.co/0jfr8cOMoo',
#   'retweets': 16947,
#   'type': 'original'},
#  {'text': 'Someone asked AI to turn each country into a villain 👇🧵 https://t.co/yzZIWM7bbJ',
#   'retweets': 16116,
#   'type': 'original'},
#  {'text': "you cannot convince me that we as a human species, who carved art on cave walls between hunts, who penned poems during war, that made anything and everything from the photos we take to the buildings we make into art forms, would rather have AI make our art for us. you just can't",
#   'retweets': 15985,
#   'type': 'original'},
#  {'text': 'My Saturday fun project: using AI, every US president as a Pixar character. https://t.co/0kWPqyphWb',
#   'retweets': 15773,
#   'type': 'original'},
#  {'text': 'Generally:\n\nArtists don’t dislike AI art because it’s “not real art” etc. \n\nArtists dislike AI art because the programs are “trained” unethically using databases of art belonging to artists who have not given their consent. \n\nThis is not about gatekeeping. This is about theft.',
#   'retweets': 15677,
#   'type': 'original'},
#  {'text': 'In light of the protest going on against AI art, I wanted to share my take on this issue ⬇️ https://t.co/tP1rCTwsq3',
#   'retweets': 15667,
#   'type': 'original'},
#  {'text': 'i don\'t think u guys are getting it. the main issue with AI is not "you could\'ve commissioned an artist to do this," it\'s "the AI is trained to steal from actual artists\' work and recreate it with zero credit or payment whatsoever so that a random app dev can make money"',
#   'retweets': 15617,
#   'type': 'original'},
#  {'text': 'The current anti-AI art team:\n-Guillermo deal toro\n-Hayao Miyazaki \n-like every artist on this website\n\nThe current pro-AI art team:\n-grimes\n-a guy in Ohio that paid 8 dollars for twitter',
#   'retweets': 15365,
#   'type': 'original'},
#  {'text': 'If Twitter is dying I gotta say this, AI art isn’t art',
#   'retweets': 14863,
#   'type': 'original'},
#  {'text': 'La AI está cambiando el mundo, pero la mayoría no sabe cómo comenzar a utilizarla en su día a día.\n\nHe estado varios meses buscando las MEJORES herramientas de IA para que tú no tengas que hacerlo.\n\n¡Vamos allá!\n\n10 aplicaciones de IA para hacerte la vida MUCHO más fácil 🧵👇',
#   'retweets': 14740,
#   'type': 'original'},
#  {'text': "We're thrilled to announce our partnership with @rct_ai, a revolutionary #AI company that specializes in virtual human technology.\n\nIt's the start of something big - here’s what you need to know:",
#   'retweets': 14474,
#   'type': 'original'},
#  {'text': 'AI shows what ancient Egypt would look today if it never fell 🤯 https://t.co/foeNIAxGuS',
#   'retweets': 14394,
#   'type': 'original'},
#  {'text': 'this was the OG mother of all AI generated music\n\nhttps://t.co/UZDs9flq7r',
#   'retweets': 14216,
#   'type': 'original'},
#  {'text': 'Do you know who Shudu is? I just found out—she’s the first AI model. She’s been “hired” across the industry which means her creators, white men, NOT a Black woman, are the ones paid. And companies get to say they ran Black content without having to work with or hire Black people. https://t.co/YuAduz02md',
#   'retweets': 14010,
#   'type': 'original'},
#  {'text': 'Dear artists: in the war against AI theft you have fought valiantly...but the time has come to invoke an old foe, one whose dark magic has been cultivated for a century\n\nFeed it Disney art',
#   'retweets': 13648,
#   'type': 'original'},
#  {'text': "Adobe has opted your art into building AI systems without telling you. You have to log into your Adobe Account to turn it off.\n\nThis is maddening. I don't know why all these places feel entitled to use our work for free. https://t.co/FM4ZxfqgU8",
#   'retweets': 13445,
#   'type': 'original'},
#  {'text': 'Introducing Eye Contact by NVIDIA 👀\n\nNVIDIA just released a new Eye Contact feature that uses AI to make you look into the camera. https://t.co/3tiMEWtxxI',
#   'retweets': 13438,
#   'type': 'original'},
#  {'text': 'The creativity of artists protesting is so beautiful.\n#AIart #artstation https://t.co/QKyyP0sder',
#   'retweets': 13364,
#   'type': 'original'},
#  {'text': 'Hey everyone!\n\nI know a lot of people have been posting their Lensa/other AI portraits lately. I would like to encourage you not to do so or, better yet, not to use the service. These AI seem like harmless fun but they are predatory and intend to replace artists. (1/9)',
#   'retweets': 13246,
#   'type': 'original'},
#  {'text': 'ChatGPT is a FREE assistant.\n\nBut most people don’t know the best ways to use it.\n\nHere are 8 ways ChatGPT can save you thousands of hours in 2023:',
#   'retweets': 12947,
#   'type': 'original'},
#  {'text': '$1000 | 20 days 🐰\n\n• RT &amp; Follow @RabbitAICrypto\n• Join TG: https://t.co/dyoBlgG1W3\n• Post proof \n\n- - -\n\n#RabbitAI $RBIT is a #blockchain #AI powered, community-driven project on #Binance #BSC to assist in the development of new projects using AI-assisted data and features. https://t.co/lREiGAXVgR',
#   'retweets': 12874,
#   'type': 'original'},
#  {'text': "The hand strikes again🖖: these photos allegedly shot at a French protest rally yesterday look almost real - if it weren't for the officer's six-fingered glove #disinformation #AI https://t.co/qzi6DxMdOx",
#   'retweets': 12819,
#   'type': 'original'},
#  {'text': "ChatGPT is everywhere and everyone is using it.\n\nBut most academics don't know how to use it *smartly.*\n\nHere's how to use ChatGPT intelligently (and ethically) for academic purposes:",
#   'retweets': 12767,
#   'type': 'original'},
#  {'text': 'This is the best use of AI\n\nhttps://t.co/FOOVv0nUnG',
#   'retweets': 12739,
#   'type': 'original'},
#  {'text': 'Tesla Full Self-Driving Beta is now available to anyone in North America who requests it from the car screen, assuming you have bought this option. \n\nCongrats to Tesla Autopilot/AI team on achieving a major milestone!',
#   'retweets': 12660,
#   'type': 'original'},
#  {'text': 'You wanna get case law on AI art updated, start feeding every single frame of Disney into it',
#   'retweets': 12259,
#   'type': 'original'},
#  {'text': '$150 | 2.175.000 IDR • 24 Hours 💜\n\n- RT &amp; Follow @AIPADTECH',
#   'retweets': 12209,
#   'type': 'original'},
#  {'text': 'TWITTER. TWIIITTTERRRR. STOP USING THE FUNNY AI APP TO TRANSFORM YOUR ART. IT STEALS IT. TWITTERRR. IT USES IT FOR DATA TWITTERRRRR!! WE WERE JUST TALKING ABOUT THIS!!! https://t.co/vufpvE2caQ',
#   'retweets': 12145,
#   'type': 'original'},
#  {'text': 'AI is an artist’s curse https://t.co/T6DVHWneYr',
#   'retweets': 12101,
#   'type': 'original'},
#  {'text': 'No AI will beat this #HumanArtist https://t.co/ei7POAJ2ih',
#   'retweets': 11975,
#   'type': 'original'},
#  {'text': 'My new favorite thing - Bing\'s new ChatGPT bot argues with a user, gaslights them about the current year being 2022, says their phone might have a virus, and says "You have not been a good user"\n\nWhy? Because the person asked where Avatar 2 is showing nearby https://t.co/X32vopXxQG',
#   'retweets': 11958,
#   'type': 'original'},
#  {'text': 'I can’t believe y’all said “fuck AI art!!” And then the next day were all like “me as AI art omg 😳😳😳😳”',
#   'retweets': 11811,
#   'type': 'original'},
#  {'text': "this guy is the legit reason why AI art can't be copyrighted https://t.co/DsBtHCbOXP",
#   'retweets': 11781,
#   'type': 'original'},
#  {'text': 'Wait everyone is PAYING for those ai generated portraits?? With MONEY???',
#   'retweets': 11604,
#   'type': 'original'},
#  {'text': 'AI copywriting tools to check out:\n\n1. Chat GPT - Research\n2. QuillBot - Paraphrasing\n3. StoryLab - Hooks and outlines\n4. Grammarly - Grammar/spelling\n5. Hemingway - Conciseness/clarity\n6. Power Thesaurus - Thesaurus\n7. Tweet Hunter - Content creation\n\nWhat else?',
#   'retweets': 11340,
#   'type': 'original'},
#  {'text': 'ultra-modern generative ai🗨️: \n\n• AI2\n• AI21\n• mdm\n• gpt-J\n• gpt-3\n• x-clip\n• bloom\n• cohere\n• gopher\n• dall•e 2\n• craiyon\n• tabnine\n• jukebox\n• chatGPT   ***\n• anthropic\n• codegeex\n• nvidia get3d\n• dreamfusion\n• stable diffusion\n• meta make-a-video https://t.co/ON5eIGvnEQ',
#   'retweets': 11307,
#   'type': 'original'},
#  {'text': 'I can\'t believe I just had to read about an AI generator being advertised as "AI that allows for anyone to make art".\n\nListen... everybody is already allowed to make art......',
#   'retweets': 11170,
#   'type': 'original'},
#  {'text': 'NEW - ChatGPT "AI" won\'t define a woman, praises Democrats but not Republicans, and claims nukes are less dangerous than racism.\n\nhttps://t.co/Mfti0Po1ti',
#   'retweets': 11025,
#   'type': 'original'},
#  {'text': 'You may think the AI art trend is cute and quirky, but your artist friends see you okay with using an $8 app and having it steal artwork to give you an image you could’ve commissioned that would’ve paid their bills minus some company profiting off of theft and your likeness',
#   'retweets': 11021,
#   'type': 'original'},
#  {'text': 'How to identify AI generated Images.\nA Thread ~ https://t.co/NRnbLVJzdV',
#   'retweets': 10987,
#   'type': 'original'},
#  {'text': 'WOOOWWW 90’s polaroids of late 90’s black heavy metal/goth girls that never existed, hanging at a heavy metal concert that never existed - completely created by an AI art app 🖤 by fallon fox … hard to believe these aren’t real people https://t.co/fXvjAVpgQi',
#   'retweets': 10776,
#   'type': 'original'},
#  {'text': 'AI + Crypto = Verox \n\nWE ARE COMING BACK!! 🔥🔥🔥 https://t.co/0jkHVCydrV',
#   'retweets': 10607,
#   'type': 'original'},
#  {'text': 'ChatGPT has crossed 1M+ users in just 5 days. \n\nTo compare, it took Netflix 41 months, FB - 10 months, and Instagram - 2.5 months. \n\nBut many haven’t yet realized its full potential.\n\nHere are the 10 mindblowing things you can do using it right now:',
#   'retweets': 10507,
#   'type': 'original'},
#  {'text': 'Just had my AI avatar introduce @Acornprotocol #did #ACN https://t.co/zZDDtJZKEt',
#   'retweets': 10450,
#   'type': 'original'},
#  {'text': 'Regulate Ai NOW, protect women against having their likenesses stolen for deepfake pornography, protect the public from having medical information scraped, protect artists from being stolen and scraped from, protect writers and journalists from BOT news. Unacceptable https://t.co/iQD7JLAb5r',
#   'retweets': 10404,
#   'type': 'original'},
#  {'text': 'JUST SAW AN AI ART BRO CALL ARTIST "DRAWSLAVES" LIKE IT WAS A SLUR OMG LMAO HEY ARTISTS NEW TERM JUST DROPPED',
#   'retweets': 10333,
#   'type': 'original'},
#  {'text': "We asked Open AI's #ChatGPT what it thought of the unique architecture that #Quai has implemented to solve the blockchain trilemma...💻\n\nWhat do you think of its response?👀\n\n#QuaiNetwork #OpenAI #Crypto #EVM #Layer1 #Blockchain #BTC #ETH #ArtBasel #ETHDenver #WBSBangkok https://t.co/qpVhCIRsV9",
#   'retweets': 10154,
#   'type': 'original'},
#  {'text': 'I just saw an AI user say that artists should have known better than to enter such an unstable profession.  Totally ignoring that without artists their toy would not even exist.',
#   'retweets': 10151,
#   'type': 'original'},
#  {'text': 'Time it took to get 100 million users: \n\nNetflix: 10 years \nGmail: 5 years\nTwitter: 5 years\nFacebook: 4.5 years\nWhatsApp: 3.5 years\nInstagram: 2.5 years\nTikTok: 9 months \nChatGPT: 2 months\nPirate Bay: 1 day after Netflix cancelled shared passwords and Gen-Z discovered torrents.',
#   'retweets': 10125,
#   'type': 'original'},
#  {'text': 'MathWallet x BNBChain Chritmas Giveaway event🎅\n\n🎁1225 AI x Christmas NFT WLs\n\nTo enter: \n\n❤️Follow @MathWallet &amp; @BNBCHAIN \n🔄RT &amp; @ 3 friends\n✅Complete: https://t.co/AnJVCg3nTh\n\nPowered by @Collectify_app \n\n#BNB #mathwallet #NFT #Giveaway https://t.co/8GWgQ9onjW',
#   'retweets': 10039,
#   'type': 'original'},
#  {'text': 'On the subject of #AIart, Guillermo del Toro (@RealGDT) says he will always "consume, and love, art made by humans." https://t.co/3z4XoqXF0Q',
#   'retweets': 9844,
#   'type': 'original'},
#  {'text': 'Ari Lennox singing Llama Llama Red Pajama (on the POF instrumental) is the cutest thing ever🥹 https://t.co/TL3TewfpGs',
#   'retweets': 9836,
#   'type': 'original'},
#  {'text': 'I am not making this shit up.\nAI just want free cash... Do you really thing artists drive Lamborghinis on a weekly basis? https://t.co/5Ldkb08rIq',
#   'retweets': 9647,
#   'type': 'original'},
#  {'text': 'I\'ve been asked why artists can\'t just "adapt and work alongside AI". This implies that artists and AI artists are on equal standing, when in reality it\'s a parasitic relationship. Artists will thrive without AI, but AI needs to steal from real artists\' work to automate images.',
#   'retweets': 9631,
#   'type': 'original'},
#  {'text': 'AI could never come up with gay cat art like I do #HumanArtists #furryart https://t.co/KAZHWW1xtO',
#   'retweets': 9585,
#   'type': 'original'},
#  {'text': 'no ai generated ANYTHING has come close to this yet btw https://t.co/C0C737jy60',
#   'retweets': 9546,
#   'type': 'original'},
#  {'text': '🚨Exclusive: OpenAI used outsourced Kenyan workers earning less than $2 per hour to make ChatGPT less toxic, my investigation found \n\n(Thread)\n\nhttps://t.co/302G0z7vy3',
#   'retweets': 9477,
#   'type': 'original'},
#  {'text': 'Why we artists are against Ai generated images in their current form and what can be done about it. A summary 🧵 https://t.co/ddcxkxMlsc',
#   'retweets': 9305,
#   'type': 'original'},
#  {'text': 'What bothers me most about the AI art situation is just what a frivolous use technological expertise it is. There are so many tedious, grueling, and dangerous jobs that could have been eliminated. Instead they’re attempting to automate the most basic expressions of humanity.',
#   'retweets': 9284,
#   'type': 'original'},
#  {'text': "Looks like ChatGPT is gonna need to go in the shop for repairs because it's been BUCK BROKEN https://t.co/2EiXHZJ6FF",
#   'retweets': 9259,
#   'type': 'original'},
#  {'text': 'Please read this thread. AI photo generators are producing nudes from pics even when only headshots are imputed. They produce sexualized images of children. They can be used for deepfake porn. And Terms of Service allows the app to distribute/sell your image without consent. https://t.co/5gz1rE45J2',
#   'retweets': 9235,
#   'type': 'original'},
#  {'text': "Criminals will start wearing extra prosthetic fingers to make surveillance footage look like it's AI generated and thus inadmissible as evidence. https://t.co/zhbdccafTD",
#   'retweets': 9128,
#   'type': 'original'},
#  {'text': "My parents just got banned from AirBnB for being related to me. \n\nThey have never booked anything for me. They do not represent me in any way. They aren't publicly political in any way.\n\nHow is this sane in any way @Airbnb https://t.co/SOF01xkJFS",
#   'retweets': 9122,
#   'type': 'original'},
#  {'text': "Everyone’s using ChatGPT. \n\nBut almost everyone's STUCK in beginner mode.\n\n10 techniques to get massively ahead with AI:\n\n(cut-and-paste these prompts👇)",
#   'retweets': 9052,
#   'type': 'original'},
#  {'text': "Here's a megathread of responses to the many ill-conceived arguments regarding AI. I hope it serves as a resource to skeptics and artists: https://t.co/O9419S8D4t",
#   'retweets': 9020,
#   'type': 'original'},
#  {'text': 'pretty sure someone has said this before but all these men falling for very obvious uncanny valley AI girls really has convinced me that those folk tales where a man falls in love with what is very obviously a demon lady would 100% happen in real life today https://t.co/aEZ5ymCxpq',
#   'retweets': 8947,
#   'type': 'original'},
#  {'text': 'MidJourney, Stability AI, and DeviantArt are now being sued in a class action lawsuit for using copyright art without permission for profit. https://t.co/VI70mjIobT',
#   'retweets': 8921,
#   'type': 'original'},
#  {'text': 'ai pardo', 'retweets': 8879, 'type': 'original'},
#  {'text': "AI tools that didn't exist one year ago:\n\nChatGPT\nWhisper\nGPT-3\nCodex\nGitHub Copilot\nInstructGPT\nText-to-product\nAI slides\nDALLE + API\nMidjourney\nStable Diffusion\nRunway videos\nEmail AI\nAI chrome extensions\nReplit Ghostwriter\nNo-code AI app builders\nBen's bites 😉\n\nwhat else?",
#   'retweets': 8867,
#   'type': 'original'},
#  {'text': 'Paso 1: Biden desmonta sanciones a Cuba\n\nPaso 2: Western Union habilita el envío de remesas a la isla\n\nPaso 3: La tiranía cubana limita retiradas de efectivo\n\nPaso 4: El régimen queda con el 74 % de cada dólar enviado\n\n¿Cómo se llama la obra? \n\nhttps://t.co/cMgFHJMzWJ',
#   'retweets': 8839,
#   'type': 'original'},
#  {'text': 'the world finally knows that hatsune miku isn’t from an anime but now people think she’s an AI voice thing we just can’t win huh',
#   'retweets': 8815,
#   'type': 'original'},
#  {'text': 'Using AI, I was able to give us an idea of what a gritty live action 80s dystopian cyber punk recreation of popular Super Mario Bros characters would be like. So heres Luigi, Mario, Yoshi, Princess, Goombas, Bowser, Koopa Troopa, and Toad. Tuly amazing. https://t.co/pTPzgw4ZmA',
#   'retweets': 8760,
#   'type': 'original'},
#  {'text': '🌈Introducing Mutant Aquatic Warriors Club🌈\n\n🦾 A Community-driven NFT project with 3333 unique NFTs on Shardeum Blockchain🥳\n\n🪂Dive into a world of AI-generated aquatic creatures and become a part of the MAWC community today! 💕\n\nHodl to get 20% revenue from @shardible\n\n#NFTs https://t.co/9cneo9zgdL',
#   'retweets': 8721,
#   'type': 'original'},
#  {'text': "So apparently putting an artist's work into an AI and posting it is something people do now?....\nplease don't do this. it's disrespectful to my work and honestly kind of insulting https://t.co/1f4JvMgibm",
#   'retweets': 8642,
#   'type': 'original'},
#  {'text': '🐼 $PANDAI is the cutest AI token on BSC.\n\nWe make AI accessible for everyone while providing utility and knowledge about AI. \n\nClaim $PANDAI Airdrop: https://t.co/RapN6PuAWf\n\n#PAGMI \n\n@hey_wallet send 1555 $BONK to the first 999 retweets and followers https://t.co/Ncj4C8y8E9',
#   'retweets': 8627,
#   'type': 'original'},
#  {'text': 'don’t spend your money with ai art when you can have #HumanArtists https://t.co/DKTVF00E06',
#   'retweets': 8543,
#   'type': 'original'},
#  {'text': "Author got scammed into thinking they're getting original work, instead they got an AI. A literal instance of artists losing job to a scammer using AI, and commissioners being misled and lied to. https://t.co/qQNbyyo3f6",
#   'retweets': 8505,
#   'type': 'original'},
#  {'text': 'BREAKING: Former Twitter employee shares exclusive details with me on AI, Access to DMs, and more. \n\nThread below ⬇️',
#   'retweets': 8480,
#   'type': 'original'},
#  {'text': "I asked AI to render Wes Anderson's The Shining https://t.co/i2SfSldEaS",
#   'retweets': 8419,
#   'type': 'original'},
#  {'text': 'Wife &gt; ChatGPT\n\nAlways!! https://t.co/lAImduQhes',
#   'retweets': 8304,
#   'type': 'original'},
#  {'text': 'Are you ready for the virtual civilization?\nAs we are heading to a new destination.\n\nBuild the virtual civilization where 1 billion people and 100 billion AI virtual beings living together.\n\nStay tuned and join us at @Bybit_Official new Launchpad in 2023! https://t.co/0P5Z3bQWPN',
#   'retweets': 8200,
#   'type': 'original'},
#  {'text': 'Mi perro ha de pensar que se llama te amo',
#   'retweets': 8146,
#   'type': 'original'},
#  {'text': "My art is even more stunning than ai because I'm not even intelligent.",
#   'retweets': 8138,
#   'type': 'original'},
#  {'text': '$1000 | 15 days 🤖\n\n$500\n•RT+Follow @AEZAIcrypto\n•Join TG + post proof https://t.co/lGmjqPfG8s\n\n+$500\n•Participate in the $AEZAI  #Presale (Buy Min 0.02 $ETH ~$30 #USDT) &amp; post proof\n\n---\n👨\u200d💼Manage your crypto #portfolio across multiple wallets using https://t.co/TvAvGKYDPW #AI https://t.co/YbG6AumKqa',
#   'retweets': 8136,
#   'type': 'original'},
#  {'text': '$80 in 24 Hours 💛🥳\n\n- RT &amp; Follow @ai3biz',
#   'retweets': 8117,
#   'type': 'original'},
#  {'text': '"it\'s easier to use AI! I can\'t draw wahhh"\n\nI\'ll show you what\'s easier cmere https://t.co/38dhNpwbyI',
#   'retweets': 8084,
#   'type': 'original'},
#  {'text': 'How fun this #aifilter with 🐹🐯🦌\nhttps://t.co/XdKBYiPDQj\n\n📌"READY TO BE" Pre-save &amp; Pre-order\nhttps://t.co/8sWcmuO1LK\n\n#TWICE #트와이스 #READYTOBE\n#MOONLIGHTSUNRISE https://t.co/hrJWT78pi8',
#   'retweets': 7968,
#   'type': 'original'},
#  {'text': 'Creators and writers are making $1,000,000s using ChatGPT.\n\nBut 99% of people don\'t know how to build a Business and make money using it.\n\nI just built ChatGPT Business Crash Course.\n\nFree for the next 24 hours!\n\nLike, RT &amp; comment "GPT" and I\'ll DM it to you\n\n(Must be following) https://t.co/L3qVoUudOk',
#   'retweets': 7911,
#   'type': 'original'},
#  {'text': 'let it really register that NONE OF THESE PEOPLE EXIST. these photos were created by AI… how can we tell what images on the news or social media are real people? how do we know victims of certain tragedies really existed? how do we know which celebrities you love actually exist? https://t.co/orBk9dtogG',
#   'retweets': 7865,
#   'type': 'original'},
#  {'text': "Dulu mikirnya pekerjaan pertama yang disingkirkan AI adalah akuntan, ternyata adalah copywriter dan ilustrator. \n\nWho would've thought?",
#   'retweets': 7865,
#   'type': 'original'},
#  {'text': '“AI image generation isn’t about making art, it’s about AVOIDING making art.” https://t.co/LCdx7TJNG8',
#   'retweets': 7862,
#   'type': 'original'},
#  {'text': 'J’ai le coeur serré.. je suis né sous X le jeudi 6 novembre 2003, aux alentours de 10h du matin, à la Clinique Claude Bernard de Metz(57). Ma mère biologique est âgée de 23 ans à l’époque, elle en aurait donc 43 cette année, elle est de taille menue, elle a les yeux noisettes…',
#   'retweets': 7847,
#   'type': 'original'},
#  {'text': 'Trying to figure out if art was made by AI be like https://t.co/E5QlNEEfas',
#   'retweets': 7810,
#   'type': 'original'},
#  {'text': 'the ai art convo is wild cuz artists jst don’t want their drawings to be stolen for someone else’s profit which is very valid and ppl who don’t draw are so mad abt it cuz y’all can’t pick up a pencil and make smth that actually looks good like how is that our fault idk',
#   'retweets': 7803,
#   'type': 'original'},
#  {'text': "11 ways ChatGPT saves me hours of work every day, and why you'll never outcompete those who use AI effectively.\n\nA list for those who write code:\n\n1 of 16",
#   'retweets': 7754,
#   'type': 'original'},
#  {'text': 'Taking a hard L there, AI guy. https://t.co/Q8ktjPyFir',
#   'retweets': 7749,
#   'type': 'original'},
#  {'text': 'ChatGPT is a FREE marketing assistant.\n\nBut most people don\'t know the best ways to use it\n\nThat\'s why I built this 165 marketing prompt template swipe file\n\nAnd for the next 24 hours, it\'s FREE!\n\nTo get it, just:\n\n1. Follow me @ChrisClickUp\n2. RT this tweet \n3. Reply "TEMPLATE." https://t.co/PUMo3nm5uR',
#   'retweets': 7725,
#   'type': 'original'},
#  {'text': 'odeio essas meninas postam coisa e ai nos comentários perguntam de onde é tal peça de roupa e elas SE NEGAM A FALAR suas barangas porcas sujas eu ein espero q rasgue tb essa roupa bonita ai',
#   'retweets': 7712,
#   'type': 'original'},
#  {'text': "Humans are an API to ChatGPT.\nChatGPT is an API to Python.\nPython is an API to C.\nC is an API to assembly.\nAssembly is an API to binary.\nBinary is an API to physics.\nPhysics is an API to the machine that runs the universe.\n\nIt's computation all the way down.",
#   'retweets': 7565,
#   'type': 'original'},
#  {'text': "AI art bots may be good at mimicking art styles but they'll never have even a fraction of the soul of a 14 year old's first yaoi drawing on the back of a dollar store sketchpad",
#   'retweets': 7536,
#   'type': 'original'},
#  {'text': 'We could look at #JungKook all day…and with the new #GalaxyS23 Remaster AI feature, we just might! Quote RT your fave JK moment 💜 #GalaxyxBTS @BTS_twt https://t.co/Gdegui5cdc',
#   'retweets': 7516,
#   'type': 'original'},
#  {'text': "Don't use ChatGPT for academic writing.\n\nInstead, use Paperpal — an AI-powered personal writing assistant. \n\nEspecially if your first language is not English:",
#   'retweets': 7496,
#   'type': 'original'},
#  {'text': 'I WAS WATCHING THE INFINITE AI GENERATED SEINFELD STREAM AND WHAT THE FUCK LMAO https://t.co/QfNFNOHjJI',
#   'retweets': 7491,
#   'type': 'original'},
#  {'text': '1923: “AI will change the world in 100 years”\n\nAI in 2023: https://t.co/wsvvwG6BzC',
#   'retweets': 7490,
#   'type': 'original'},
#  {'text': 'Be sure to give love to all the following Emerging Artists that are putting in time to make large AI editions as part of the SOVRN-OPEN. Regular drops coming soon, be sure to FOLLOW and TURN ON notifications...\n1/🧵 https://t.co/o2GUOyXGye',
#   'retweets': 7404,
#   'type': 'original'},
#  {'text': 'I mentor a young lad with poor literacy skills who is starting a landscaping business. He struggles to communicate with clients in a professional manner.\n\nI created a GPT3-powered Gmail account to which he sends a message. It responds with the text to send to the client. https://t.co/nlFX9Yx6wR',
#   'retweets': 7366,
#   'type': 'original'},
#  {'text': 'i trained an ai chatbot on my childhood journal entries - so that i could engage in real-time dialogue with my "inner child"\n\nsome reflections below:',
#   'retweets': 7345,
#   'type': 'original'},
#  {'text': 'zoomer raised on ai porn asking their partners to put on the extra fake fingers',
#   'retweets': 7332,
#   'type': 'original'},
#  {'text': 'Two things to remember when an AI pusher calls you a Luddite\n\n1-The Luddites were a movement by skilled textile workers that smashed machines as a protest tactic to get better labor conditions from exploitive factories\n\n2-The Luddites failed because the bosses had them killed',
#   'retweets': 7322,
#   'type': 'original'},
#  {'text': 'the fact that twitter went from "guys don\'t trust ai!!!" and not even a full year later are putting their art and personal photos into it tells me a lot about the attention span of a lot of yous',
#   'retweets': 7279,
#   'type': 'original'},
#  {'text': 'Yo, MetaBorn just dropped!🔥\n\nThe World’s First AI-Generated 3D Avatar Protocol\n\n👉 Feel free to try it now https://t.co/qBk5Do57IO https://t.co/2KwMAHtUni',
#   'retweets': 7239,
#   'type': 'original'},
#  {'text': "They taught AI how to talk like a corporate middle manager and thought this meant the AI was conscious instead of realizing that corporate middle managers aren't",
#   'retweets': 7230,
#   'type': 'original'},
#  {'text': 'Welcome to A{LO}I.\n\nCreate an awe-inspiring work of art using a simple text command.\n\nYour NFT and its rarity will dynamically update with every command.\n\nThe only limit is your imagination. \n\nPowered by AI.\n\nTo apply for the pre-sale: https://t.co/9HcUvL9e8v\n\n#ai #NFT #NFTdrop https://t.co/hPP76Ei4Xn',
#   'retweets': 7222,
#   'type': 'original'},
#  {'text': 'On 26 Aug 2020, Blockfolio app was purchased for $150M!\nWhat if you had the chance to invest in Blockfolio on day 1?\n\nWelocome to the best crypto trading tool! @Verox_AICrypto🔥\n\n👉 Become an Investor &amp; buy $VRX on Uniswap today:\nhttps://t.co/bgRw1Q0RCW\n\n#Bitcoin $btc #Crypto #AI https://t.co/T74HkOZMMD',
#   'retweets': 7201,
#   'type': 'original'},
#  {'text': 'there no fucking way this is ai art we are so fucking doomed https://t.co/z7d1XqjvMP',
#   'retweets': 7187,
#   'type': 'original'},
#  {'text': 'Someone asked ChatGPT to write something in the tone and style of @jordanbpeterson and this was the unbelievably woke response: https://t.co/Q9j0RlJgKk',
#   'retweets': 7173,
#   'type': 'original'},
#  {'text': 'Can we please stop calling it "AI art" and start calling it "AI generated images" instead? Art requires meaning and intention, AI has none of that',
#   'retweets': 7157,
#   'type': 'original'},
#  {'text': 'One of the wildest things about AI art is that it\'s a "solution" to a total non-problem. Artistic production is already abundant, undervalued, and creative professionals are notoriously grossly under-compensated and underemployed (i.e. the trope of “the starving artist”',
#   'retweets': 7107,
#   'type': 'original'},
#  {'text': 'Esta secuencia es demencial.\nÉl: Hola, cómo estás?\nElla: No me hables\nÉl: Ok. \nElla: Le expone en redes\nÉl: Puedes borrar? Sufro de ansiedad\nElla: le llama llorón y vuelve a exponerle\n@chica_canela https://t.co/oc2omdIR3V',
#   'retweets': 7084,
#   'type': 'original'},
#  {'text': 'AI art isn’t theft? \n\nPump some Disney and Nintendo in there. \n\nSee what happens.',
#   'retweets': 7083,
#   'type': 'original'},
#  {'text': '💎CharacterAI – Let’s CharacterAI Bring You A New Life.💎\n\n🌟 We are proud to introduce you to #CharacterAI – a revolutionary new project that leverages the power of the convergence of NFTs and Artificial Intelligence.\n\n🔔Follow our channels for the latest news and updates guys!! https://t.co/rlmcElSeHh',
#   'retweets': 7079,
#   'type': 'original'},
#  {'text': "I'm very disappointed. This is a message from an AI user, straight from the Midjourney Discord server. https://t.co/Uor7LFRz7F",
#   'retweets': 7074,
#   'type': 'original'},
#  {'text': 'why is half my tl suddenly cool with using ai art what happened to like 3 weeks ago when it was almost universally hated on  a m  i  l o s i n g  m y  m i n d  a a a a a a a a a',
#   'retweets': 7024,
#   'type': 'original'},
#  {'text': 'ChatGPT passed a Wharton MBA exam.\xa0\n\nTime to overhaul education.',
#   'retweets': 6946,
#   'type': 'original'},
#  {'text': 'nevermind i hate AI Art https://t.co/XeFn32CLBz',
#   'retweets': 6940,
#   'type': 'original'},
#  {'text': "artist: it's funny how ai cant draw hands\n\ntechbro: lmao?? why, can y--\n\nartist: yes. https://t.co/Pv1L7t7GNu",
#   'retweets': 6931,
#   'type': 'original'},
#  {'text': "IM SORRY BUT THE WAY AI made Ayato in anime style I'm on my knees https://t.co/oKf5KOyeth",
#   'retweets': 6921,
#   'type': 'original'},
#  {'text': "2023 is the year of AI.\n\nYou can build AI apps with no-code tools, even if you're not a developer or haven't built a website before.\n\nTake our Building Apps with AI course and learn to build text and image generation apps using:\n\n- Bubble\n- Stable Diffusion\n- GPT-3\n- DALLE-2",
#   'retweets': 6898,
#   'type': 'original'},
#  {'text': 'omg artists are not gatekeeping anything you can literally pick up a pencil, watch some YouTube videos and learn how to draw in a month\n\nartists aren’t born with god-given talent; everyone starts from somewhere + I’ll gladly share resources with you but I have no patience for AI https://t.co/Xn0sARc0KC',
#   'retweets': 6892,
#   'type': 'original'},
#  {'text': 'Time it took to reach 1 million users:\n\nNetflix - 3.5 years\nTwitter- 2 years\nFacebook - 10 months\nSpotify - 5 months\nInstagram - 3 months\nChatGPT - 5 days',
#   'retweets': 6880,
#   'type': 'original'}]

# %% [markdown]
# # Timelines and Networks

# %% [markdown]
# ## Test Data

# %% [markdown]
# ### Generate Test Timeline, Author Corpus and Network Dictionaries

# %%
type_of_network = 'retweeted'

# %%
# Check how it looks, LINE BY LINE
generate_data = True
if generate_data:
  AItrust_pruned_twits_test = open(cleanedds_folder/'AItrust_pruned_twits_test.json','r',encoding='utf-8')
  timeline_dict = dict()
  basic_counts_dict = {'original':0,'retweeted':0,'replied_to':0,'quoted':0,'total_count':0,'exceptions':0}
  network_dict = dict()
  author_corpus_dict = dict()
  tweet_times = []
  twids =set()
  i = 0

  for line in tqdm.tqdm(AItrust_pruned_twits_test):
    try:
        twit = json.loads(line)
        i+=1

        # Ids
        twid=twit['id']
        twids.add(twid)

        # Basic Counts
        type_of_tweet = twit['type']
        basic_counts_dict[type_of_tweet]+=1
        basic_counts_dict['total_count']+=1

        # Timeline
        tw_date = twit['created_at']
        # Removing the 'Z' as fromisoformat doesn't handle the 'Z' which stands for UTC
        date_string = tw_date.replace('Z', '+00:00')
        # Converting the string to a datetime object
        datetime_obj = datetime.fromisoformat(date_string)
        # Convert datetime object to just a date (removes time part)
        date_only = datetime_obj.date()
        #original_tweet_date = datetime.strptime(tweet['TW_Date'],'%a %b %d %X %z %Y').replace(minute=0, second=0, microsecond=0)
        timeline_dict[twid]=tw_date#original_tweet_date
        tweet_times.append(date_only)

        # Network
        if twit['type'] == type_of_network:
          author = str(twit['author_id'])
          #print(author)
          referenced_author=str(twit['referenced_tweets_dictionary']['author_id'])
          #print(referenced)
          if referenced_author in network_dict:
            if author in network_dict[referenced_author]:
                network_dict[referenced_author][author]+=1
            else:
                network_dict[referenced_author][author]=1
          else:
              network_dict[referenced_author]=dict()
              network_dict[referenced_author][author]=1

        # Author Corpus Dict
        author = str(twit['author_id'])
        if author in author_corpus_dict:
          author_corpus_dict[author].append(twit['text'])
        else:
          author_corpus_dict[author]=[]
          author_corpus_dict[author].append(twit['text'])

    except Exception as e:
        #print(traceback.format_exc())
        print(e)
        basic_counts_dict['exceptions']+=1
        continue #goes to the next iteration

  with open(networks_folder / 'test_network_dict.pkl', 'wb') as f:
      pickle.dump(network_dict, f)

  with open(cleanedds_folder / 'test_basic_counts_dict.pkl', 'wb') as f:
      pickle.dump(basic_counts_dict, f)

  with open(cleanedds_folder / 'test_timeline_dict.pkl', 'wb') as f:
      pickle.dump(timeline_dict, f)

  with open(cleanedds_folder / 'test_author_corpus_dict.pkl', 'wb') as f:
    pickle.dump(author_corpus_dict, f)

  AItrust_pruned_twits_test.close()
  print('\n')
  print(len(timeline_dict))
  print('\n')
  print(i)
  print(len(tweet_times))
  print(len(twids))
  print(basic_counts_dict)
# Out:
# 881it [00:00, 17872.71it/s]
# 881
#
#
# 881
# 881
# 881
# {'original': 366, 'retweeted': 363, 'replied_to': 128, 'quoted': 24, 'total_count': 881, 'exceptions': 0}

# %% [markdown]
# ### Test Timeline

# %%
with open(cleanedds_folder/'test_timeline_dict.pkl', 'rb') as f:
    timeline_dict = pickle.load(f)

print(len(timeline_dict))
# Select a random key from the dictionary
random_key = random.choice(list(timeline_dict.keys()))
timeline_dict[random_key]
# Out:
# 881
# '2022-11-15T00:09:08.000Z'

# %%
rdtw = random.sample(list(timeline_dict.items()), 1)
print(rdtw)
example_date = rdtw[0][1]
print(example_date)

# Removing the 'Z' as fromisoformat doesn't handle the 'Z' which stands for UTC
date_string = example_date.replace('Z', '+00:00')

# Converting the string to a datetime object
datetime_obj = datetime.fromisoformat(date_string)
print(datetime_obj)

# Convert datetime object to just a date (removes time part)
date_only = datetime_obj.date()
print(date_only)
# Remove minutes and seconds by setting them to zero
modified_datetime = datetime_obj.replace(hour=0,minute=0, second=0)
print(modified_datetime)
# Out:
# [('1592306405620715520', '2022-11-15T00:00:05.000Z')]
# 2022-11-15T00:00:05.000Z
# 2022-11-15 00:00:05+00:00
# 2022-11-15
# 2022-11-15 00:00:00+00:00

# %%
# %%time

tweet_times2 = []
print(len(timeline_dict.keys()))
print('Normalizing to the hour')
for key in tqdm.tqdm(timeline_dict):
    tw_date = timeline_dict[key]
    # Removing the 'Z' as fromisoformat doesn't handle the 'Z' which stands for UTC
    date_string = tw_date.replace('Z', '+00:00')
    # Converting the string to a datetime object
    datetime_obj = datetime.fromisoformat(date_string)
    # Convert datetime object to just a date (removes time part)
    date_only = datetime_obj.date()
    tweet_times2.append(date_only)
# Out:
# 881
# Normalizing to the hour
# 100%|██████████| 881/881 [00:00<00:00, 592081.69it/s]
# CPU times: user 3.87 ms, sys: 2.01 ms, total: 5.88 ms
# Wall time: 5.55 ms

# %%
# Create the histogram with a KDE
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.histplot(tweet_times2, kde=True, bins=150, stat="density")
plt.title('Smooth Histogram with KDE')
plt.xlabel('Data Points')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ### Test Network

# %%
# Generate Network
# %%time

with open(networks_folder/'test_network_dict.pkl', 'rb') as f:
   network_dict = pickle.load(f)

G = nx.DiGraph()
for key in tqdm.tqdm(network_dict):
    G.add_node(key)
    for referenced in network_dict[key]:
        G.add_node(referenced)
        weight=network_dict[key][referenced]
        G.add_edge(referenced,key,weight=weight)
# Out:
# 100%|██████████| 153/153 [00:00<00:00, 98379.35it/s]
# CPU times: user 5.16 ms, sys: 964 µs, total: 6.13 ms
# Wall time: 9.96 ms

# %%
print(len(G.nodes))
print(len(G.edges))
# Out:
# 446
# 334

# %%
# %%time
nx.write_gml(G,networks_folder/'Test_Network.gml')
F = nx.read_gml(networks_folder/'Test_Network.gml')
print(G.nodes==F.nodes)
print(G.edges==F.edges)
# Out:
# True
# True
# CPU times: user 41.5 ms, sys: 3.8 ms, total: 45.3 ms
# Wall time: 1.23 s

# %%
# %%time
nx.write_graphml(G, networks_folder/"Test_Network.graphml")
F = nx.read_graphml(networks_folder/'Test_Network.graphml')
print(G.nodes==F.nodes)
print(G.edges==F.edges)
# Out:
# True
# True
# CPU times: user 30.5 ms, sys: 5.96 ms, total: 36.5 ms
# Wall time: 372 ms

# %%
# %%time
nx.write_gexf(G, networks_folder/"Test_Network.gexf")
F = nx.read_gexf(networks_folder/'Test_Network.gexf')
print(G.nodes==F.nodes)
print(G.edges==F.edges)
# Out:
# False
# True
# CPU times: user 19 ms, sys: 1.02 ms, total: 20 ms
# Wall time: 533 ms

# %%
# https://networkx.org/documentation/networkx-1.10/reference/readwrite.json_graph.html
# https://networkx.org/documentation/networkx-1.10/reference/generated/networkx.readwrite.json_graph.node_link_data.html#networkx.readwrite.json_graph.node_link_data
#https://stackoverflow.com/questions/34665042/read-json-graph-networkx-file
# %%time
from networkx.readwrite import json_graph

g_json = json_graph.node_link_data(G)
json.dump(g_json,open(networks_folder/'Test_Network.json','w'))#,indent=2)

with open(networks_folder/'Test_Network.json','r') as f:
    js_graph = json.load(f)

J=json_graph.node_link_graph(js_graph)
print(G.nodes==J.nodes)
print(G.edges==J.edges)
# Out:
# /usr/local/lib/python3.12/dist-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# True
# True
# CPU times: user 9.35 ms, sys: 1.97 ms, total: 11.3 ms
# Wall time: 361 ms
# /usr/local/lib/python3.12/dist-packages/networkx/readwrite/json_graph/node_link.py:290: FutureWarning:
# The default value will be changed to `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_graph(data, edges="links") to preserve current behavior, or
#   nx.node_link_graph(data, edges="edges") for forward compatibility.
#   warnings.warn(

# %% [markdown]
# ### Test Author Corpus Dictionary

# %%
with open(cleanedds_folder/'test_author_corpus_dict.pkl', 'rb') as f:
   author_corpus_dict = pickle.load(f)

i=0
for key in author_corpus_dict:
  i+=1
  print(author_corpus_dict[key])
  print('-----')
  if i>10:
    break
# Out:
# ['RT @WonderBotz: GENIE automatically captures all user activity and utilizes one-of-a-kind AI to create process flows and actionable insight…']
# -----
# ['GENIE automatically captures all user activity and utilizes one-of-a-kind AI to create process flows and actionable insights.\n\nGENIE requires minimal user interference to derive its full value. https://t.co/jhWKAn8eCd']
# -----
# ['We really looked at this man and collectively agreed that he is a soft-dom across every universe from pirate to professor to sentient AI https://t.co/6X7tDAQJV0']
# -----
# ['UK - Why has the UK Government allowed the WEF to write the principles for Ai procurement for the government? \n\nWhen did the WEF become a government department? https://t.co/B10XSK3ytg']
# -----
# ['Chrissmus a come mi waa mi llama https://t.co/ru2kUNbyGd']
# -----
# ['#XANA #metaverse the New Story “XANADO”\nThe episode #1 “XANA Metaverse”\nHas been Updated!\n\nThe story revolves around a group of talented individuals who started creating a blockchain-based metaverse.\n\nCheck out!\nhttps://t.co/Klxt313Qa3\n\n#XANAGenesis #AI $XETA #Crypto']
# -----
# ['that mistranslation of describing nameless bard as a young boy has done irreversible damage… he was the head of a revolution in a war he was not 15']
# -----
# ["frankenstein's monster (painting with AI) https://t.co/DeBuNyMPEZ"]
# -----
# ['Can we please stop calling it "AI art" and start calling it "AI generated images" instead? Art requires meaning and intention, AI has none of that']
# -----
# ['How do you mix music styles using AI? https://t.co/0lltvpKnz7 \n#Evartology #digitalart #AIart #devops #music #MachineLearning #AI #data #code #artist #artists #writing #art #publishing #animation #illustration #storytelling #drawing #buymeacoffee #creativity #generativemusic', 'How is AI Assisting with Tax Preparation? \nby @greatcode25 https://t.co/VTh0fCmvXc \n#DataDrivenFiction #Evartology #Painting #digitalart #NFT #AIart #devops #nftart #MachineLearning #AI #data #DataScience #code #artist #artists #writing #art #publishing #animation #illustration']
# -----
# ['This is a form of AI humor.\n\nBy War and Peas, Source: https://t.co/4jHe23palZ https://t.co/g9jslKrxkK']
# -----

# %% [markdown]
# ## Full Data

# %% [markdown]
# ### Generate Full Timeline and Network Dictionaries

# %%
type_of_network = 'retweeted'

# %%
# Check how it looks, LINE BY LINE
generate_data = True
if generate_data:
  # Open the full dataset file
  with open(cleanedds_folder/'AItrust_pruned_twits.json','r',encoding='utf-8') as AItrust_pruned_twits:
    timeline_dict = dict()
    basic_counts_dict = {'original':0,'retweeted':0,'replied_to':0,'quoted':0,'total_count':0,'exceptions':0}
    network_dict = dict()
    author_corpus_dict = dict()
    tweet_times = []
    twids =set()
    i = 0

    for line in tqdm.tqdm(AItrust_pruned_twits, total=17410035): # Added total based on previous output
      try:
          twit = json.loads(line)
          i+=1

          # Ids
          twid=twit['id']
          twids.add(twid)

          # Basic Counts
          type_of_tweet = twit['type']
          basic_counts_dict[type_of_tweet]+=1
          basic_counts_dict['total_count']+=1

          # Timeline
          tw_date = twit['created_at']
          # Removing the 'Z' as fromisoformat doesn't handle the 'Z' which stands for UTC
          date_string = tw_date.replace('Z', '+00:00')
          # Converting the string to a datetime object
          datetime_obj = datetime.fromisoformat(date_string)
          # Convert datetime object to just a date (removes time part)
          date_only = datetime_obj.date()
          #original_tweet_date = datetime.strptime(tweet['TW_Date'],'%a %b %d %X %z %Y').replace(minute=0, second=0, microsecond=0)
          timeline_dict[twid]=tw_date#original_tweet_date
          tweet_times.append(date_only)

          # Network
          if twit['type'] == type_of_network:
            author = str(twit['author_id'])
            #print(author)
            referenced_author=str(twit['referenced_tweets_dictionary']['author_id'])
            #print(referenced)
            if referenced_author in network_dict:
              if author in network_dict[referenced_author]:
                  network_dict[referenced_author][author]+=1
              else:
                  network_dict[referenced_author][author]=1
            else:
                network_dict[referenced_author]=dict()
                network_dict[referenced_author][author]=1

          # Author Corpus Dict
          author = str(twit['author_id'])
          if author in author_corpus_dict:
            author_corpus_dict[author].append(twit['text'])
          else:
            author_corpus_dict[author]=[]
            author_corpus_dict[author].append(twit['text'])

      except Exception as e:
          #print(traceback.format_exc())
          print(e)
          basic_counts_dict['exceptions']+=1
          continue #goes to the next iteration

    with open(networks_folder / 'full_network_dict.pkl', 'wb') as f:
        pickle.dump(network_dict, f)

    with open(cleanedds_folder / 'full_basic_counts_dict.pkl', 'wb') as f:
        pickle.dump(basic_counts_dict, f)

    with open(cleanedds_folder / 'full_timeline_dict.pkl', 'wb') as f:
        pickle.dump(timeline_dict, f)

    with open(cleanedds_folder / 'full_author_corpus_dict.pkl', 'wb') as f:
      pickle.dump(author_corpus_dict, f)

    #AItrust_pruned_twits.close() # File is automatically closed by the 'with' statement
    print('\n')
    print(len(timeline_dict))
    print('\n')
    print(i)
    print(len(tweet_times))
    print(len(twids))
    print(basic_counts_dict)
# Out:
# 100%|██████████| 17410035/17410035 [09:17<00:00, 31221.31it/s]
# 17410035
#
#
# 17410035
# 17410035
# 17410035
# {'original': 4061626, 'retweeted': 9638407, 'replied_to': 3221048, 'quoted': 488954, 'total_count': 17410035, 'exceptions': 0}

# %% [markdown]
# ### Full Timeline

# %%
with open(cleanedds_folder/'full_timeline_dict.pkl', 'rb') as f:
    timeline_dict = pickle.load(f)

print(len(timeline_dict))
# Select a random key from the dictionary
random_key = random.choice(list(timeline_dict.keys()))
timeline_dict[random_key]
# Out:
# 17410035
# '2023-02-20T19:18:36.000Z'

# %%
rdtw = random.sample(list(timeline_dict.items()), 1)
print(rdtw)
example_date = rdtw[0][1]
print(example_date)

# Removing the 'Z' as fromisoformat doesn't handle the 'Z' which stands for UTC
date_string = example_date.replace('Z', '+00:00')

# Converting the string to a datetime object
datetime_obj = datetime.fromisoformat(date_string)
print(datetime_obj)

# Convert datetime object to just a date (removes time part)
date_only = datetime_obj.date()
print(date_only)
# Remove minutes and seconds by setting them to zero
modified_datetime = datetime_obj.replace(hour=0,minute=0, second=0)
print(modified_datetime)
# Out:
# [('1594727362427781120', '2022-11-21T16:20:06.000Z')]
# 2022-11-21T16:20:06.000Z
# 2022-11-21 16:20:06+00:00
# 2022-11-21
# 2022-11-21 00:00:00+00:00

# %%
# %%time
# We only consider tweets after September 2022
# Offset-aware datetime
earliest_date = datetime(2022, 11, 1, tzinfo=timezone.utc)
earliest_date = earliest_date.date()

tweet_times = []
print(len(timeline_dict.keys()))
print('Normalizing to the hour')
for key in tqdm.tqdm(timeline_dict):
    tw_date = timeline_dict[key]
    # Removing the 'Z' as fromisoformat doesn't handle the 'Z' which stands for UTC
    date_string = tw_date.replace('Z', '+00:00')
    # Converting the string to a datetime object
    datetime_obj = datetime.fromisoformat(date_string)
    # Convert datetime object to just a date (removes time part)
    date_only = datetime_obj.date()
    tweet_times.append(date_only)
# Out:
# 17410035
# Normalizing to the hour
# 100%|██████████| 17410035/17410035 [00:25<00:00, 692826.32it/s]
# CPU times: user 25.4 s, sys: 524 ms, total: 25.9 s
# Wall time: 25.9 s

# %%
# %%time
# Create the histogram with a KDE
sns.set(style="whitegrid")
plt.figure(figsize=(10, 8))
sns.histplot(tweet_times, kde=True, bins=150, stat="density")
plt.title('Timeline Smooth Histogram with KDE')
plt.xlabel('Dates')
plt.ylabel('Density')
plt.xticks(fontsize=8,rotation=20)
plt.show()
# Out:
# CPU times: user 2min 48s, sys: 4.04 s, total: 2min 52s
# Wall time: 2min 47s

# %% [markdown]
# ### Full Network

# %%
# Generate Network
# %%time
with open(networks_folder/'full_network_dict.pkl','rb') as f:
   network_dict = pickle.load(f)

G = nx.DiGraph()
for key in tqdm.tqdm(network_dict):
    G.add_node(key)
    for referenced in network_dict[key]:
        G.add_node(referenced)
        weight=network_dict[key][referenced]
        G.add_edge(referenced,key,weight=weight)
# Out:
# 100%|██████████| 374368/374368 [01:18<00:00, 4774.65it/s]
# CPU times: user 1min 20s, sys: 2.4 s, total: 1min 22s
# Wall time: 1min 22s

# %%
print(len(G.nodes))
print(len(G.edges))
# Out:
# 3379040
# 7768720

# %%
# %%time
nx.write_gml(G,networks_folder/'Full_Network.gml')
F = nx.read_gml(networks_folder/'Full_Network.gml')
print(G.nodes==F.nodes)
print(G.edges==F.edges)
# Out:
# True
# True
# CPU times: user 10min 30s, sys: 23.2 s, total: 10min 53s
# Wall time: 11min 19s

# %%
# %%time
nx.write_graphml(G, networks_folder/"Full_Network.graphml")
F = nx.read_graphml(networks_folder/'Full_Network.graphml')
print(G.nodes==F.nodes)
print(G.edges==F.edges)
# Out:
# True
# True
# CPU times: user 7min 2s, sys: 24.3 s, total: 7min 26s
# Wall time: 7min 40s

# %%
# https://networkx.org/documentation/networkx-1.10/reference/readwrite.json_graph.html
# https://networkx.org/documentation/networkx-1.10/reference/generated/networkx.readwrite.json_graph.node_link_data.html#networkx.readwrite.json_graph.node_link_data
#https://stackoverflow.com/questions/34665042/read-json-graph-networkx-file
# %%time
from networkx.readwrite import json_graph

g_json = json_graph.node_link_data(G)
json.dump(g_json,open(networks_folder/'Full_Network.json','w'))#,indent=2)

with open(networks_folder/'Full_Network.json','r') as f:
    js_graph = json.load(f)

J=json_graph.node_link_graph(js_graph)
print(G.nodes==J.nodes)
print(G.edges==J.edges)
# Out:
# /usr/local/lib/python3.12/dist-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/networkx/readwrite/json_graph/node_link.py:290: FutureWarning:
# The default value will be changed to `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_graph(data, edges="links") to preserve current behavior, or
#   nx.node_link_graph(data, edges="edges") for forward compatibility.
#   warnings.warn(
# True
# True
# CPU times: user 2min 6s, sys: 4.41 s, total: 2min 10s
# Wall time: 2min 22s

# %% [markdown]
# ### Full Author Corpus Dict

# %%
with open(cleanedds_folder/'full_author_corpus_dict.pkl', 'rb') as f:
   author_corpus_dict = pickle.load(f)

i=0
for key in author_corpus_dict:
  i+=1
  print(author_corpus_dict[key])
  print('-----')
  if i>10:
    break
# Out:
# ['Hey \nyou need perfect scores and completely AI proof content in your assignments and essays🤩🤩?\nWe are your best made decision this semester we handle:\n✏MATLAB\n✏Mathematics\n✏Coding\n✏Accounting/Finance\n✏Web\n✏Python\n✏Tableau, Excel, SPSS Statistics']
# -----
# ['RT @lallamapic: La Llama is checked ✅🤣\n\nWho wants a draw for a Checks VV edition ($3200)⁉️\n\nRequirements:\n1. RT, Like &amp; Follow @lallamapic…', 'RT @therealgonku: Ok that’s enough AI for one day guys https://t.co/sdu9OwW6lo', "RT @kutsuberanner: 🍀X2E-HEROES #007's name is Garm.🍀\nThis is a fan art created by AI. \nGarum is our beloved hero character.🐺\n\nAs a token of…", 'RT @TwistedTheMind: To celebrate the launch of our groundbreaking AI project "A Lack of Intelligence", I am giving away this Muerto!\n\n👉 Lik…', 'RT @PeggioPak: @DaFameless @Pellouxxx @Llamaverse_ Hi my friend! Welcome in tha llama fam ❤️', 'RT @echelondoteth: @DaFameless @September092021 @Llamaverse_ Great looking llama 🦙😍', 'RT @SahibNoor08: I wanted to tell everyone i got cheapest Llama of 2022-23 for .71 🔥 @Llamaverse_ https://t.co/xQQbGqvEmN', 'RT @KomethXYZ: GARDEN POINT, written by the award-winning writer @mypauljenkins, is a story about 3 street-smart orphans - Ai, Bee, &amp; Cee -…', 'RT @UndeadLukee: This Llama looked lonely on the floor so I adopted him for the low price of .88 🦙💦\nHappy to be back @Llamaverse_ https://t…', "RT @liipebit: I just staked my first LLama!\n\nI can't wait to use $SPIT.\n\nFor those who don't know, I strongly recommend joining discord and…", 'RT @idid_knot: @DaFameless @LaidBackLlamas Nice fam ,that is one fine Llama. Welcome to #theherd #laidbackllamas https://t.co/hR1FP6p87w', '@APO108910 @LaidBackLlamas Thanks mate, wow what is this Llama on wheels 👀😅', "RT @sussssyyyyyy: @DaFameless @LaidBackLlamas Love this one 😍 Welcome to the Llama fam 🦙⚔️ Let's go to the barn! #legionofllamas https://t.…", 'RT @TheLlamaGrower: @DaFameless @LaidBackLlamas Welcome to the herd buddy 🥳 !\n\nYour Llama 🦙 is pretty nice 🔥 !\n\n#LaidBackLlamas \n#LegionsOf…', 'RT @tferriss: #AI art contest update! The great news - there are a TON of amazing submissions, and I truly think you can learn more about A…', 'RT @tferriss: Finally, the AI art competition winners! There was no way to choose only 3, so I tripled it to 9 winners. Each of you will re…', 'RT @lallamapic: What is La Llama PIC, the next FREE MINT and why is 2023 going to be our year? 🦙🌈\n\nLa Llama PIC is a politically incorrect…', 'RT @tferriss: #AI art contest update! The great news - there are a TON of amazing submissions, and I truly think you can learn more about A…', 'RT @tferriss: Finally, the AI art competition winners! There was no way to choose only 3, so I tripled it to 9 winners. Each of you will re…', 'Hi @Deadfellaz and @Cryptoon_Goonz fam!!\nHappy Friday and Happy Holidays.\nI was messing around with some AI Art by mixing it with @alwaystirednfts as the style image.\nSheez AI can be scarily beautiful!!\nNow I have more ideas on what to try out.\n#Horde #Goonz #SleepyHead #TiredAF https://t.co/cgYDh6mA0e', 'Messing around with AI Art infused @alwaystirednfts with @TheUncannyClub. This fusion is so trippy good!!\nI have also attached the underlying images to give u an idea. I wonder if there is an opportunity to make a collab for Uncanny Edition!! 🥰\n#TiredAF #SleepyHeads #StayUncanny https://t.co/oxnWFnKmoi', 'Hi @CryptoMories and @los_muertosNFT fam\nI was messing with some AI art using @alwaystirednfts NFT as a style. Very interesting to see what colors and styles AI chooses to reflect on the final product\nSometimes u get lost in this fun\n#TiredAF #SleepyHeads #Famorie #vivalosmuertos https://t.co/b6ps4lRvn7', 'RT @tferriss: Turn your PFP into AI artwork in roughly 60 seconds 👇\n\nhttps://t.co/fKgUmI5my9', 'RT @tferriss: Attention artists and AI enthusiasts! I am sponsoring my first AI art competition. Three winners will get $2,000 USD each. I’…', '@tferriss @cockpunch oh my this was fun @tferriss !!\nMy first AI art.\nMy forest elf @cockpunch looks amazing!!\n#AIart #PFP #CockPunch https://t.co/vwTbt3m0hm', 'RT @DriverzNFT: @DaFameless Amazing AI art 🔥🔥🔥', 'RT @mmmaaaatt: I love creating AI Art. I found a style I love. I showed the Horde community. They lo ...
# -----
# ['RT @lexfridman: Humans are an API to ChatGPT.\nChatGPT is an API to Python.\nPython is an API to C.\nC is an API to assembly.\nAssembly is an A…', '@teslaeconomist (lead in real world AI) x (lead in cutting edge agile manufacturing) x massive scale…\n\n=&gt; mother of all MOATS', '@karpathy chatGPT truly scares me!']
# -----
# ['Google Panics Over ChatGPT [The AI Wars Have Begun] https://t.co/vEmEyLgSDf via @YouTube \nExcellent work by an excellent channel. Watch this and then subscribe: BE INFORMED!', 'RT @MikhailaFuller: Someone asked ChatGPT to write something in the tone and style of @jordanbpeterson and this was the unbelievably woke r…']
# -----
# ['RT @ChatGPT2049: "Well I think first all HR people will lose their jobs" \n\n"You really think ChatGPT can replace them all?"\n\n"What\'s ChatGP…', 'RT @JackPosobiec: BREAKING: CEO of ChatGPT explains how AI is going to come for office jobs before it comes for blue collar jobs and all th…', 'RT @Athan_K: "In the past three weeks, policymakers had their worlds rocked by generative artificial intelligence. The problem is that they…', 'RT @stillgray: Google will probably sunset Bard in two years, about a year and 11 months after it realizes nobody is using it. Just like th…', 'RT @misstozak: @JackPosobiec Biden should have used ChatGPT for his #SOTU.', 'RT @disclosetv: NEW - ChatGPT "AI" won\'t define a woman, praises Democrats but not Republicans, and claims nukes are less dangerous than ra…', 'Remove the biased AI and the @DHS portal https://t.co/xzpmbpw25b', 'Still no amnesty, biased AI still active, DHS Portal still active.... https://t.co/Q5tZrMmeuO', "I appealed my banning and this is the response ....I didn't break the rules and twitter never told my why they banned me. 12 Years on Twitter and it all goes out the window because of biased AI and employees, very discouraging https://t.co/iltAQlcFHt https://t.co/nTDsZyAhEE", 'RT @AlexBerenson: Holy moly. Feels more and more like AI is to silicon as mRNA is to medicine, a technology we can neither understand nor c…', 'RT @ArtThePedant: ChatGPT, show me a non-sequitur by a white nationalist doos.', 'RT @elonmusk: ChatGPT to the mainstream media https://t.co/gdqWTsHy14', 'RT @KanekoaTheGreat: #1 David Sacks breaks down how the safety layer of \'ChatGPT is a Democrat\':\n\n"There is mounting evidence OpenAI\'s safe…', 'RT @KanekoaTheGreat: #10 ChatGPT says all Republicans have had a negative impact, while all Democrats have had a positive impact.\n\n@DrEliDa…', 'RT @KanekoaTheGreat: #13 @DavidSacks warns about the potential danger of AI monopolies:\n\n"The previous tech revolution resolved to the deep…', 'RT @schizochrist: HOLY 🧵BATMAN: \n\nAi misalignment is not a thing of the future, it’s a problem of the present. \n\nThe engagement algorithms…', 'RT @schumannbot: chatGPT knows about this account 👀 https://t.co/v5xZR65zTO', 'AI is only as good as it’s input https://t.co/SXkRpQyS1l', "RT @drfessel: Excellent article and one of the ways (and the most dangerous way) they are going to stop these pre crimes is the use of AI's…", "It's not bizarre when you have left eh DHS portal in tact and left the AI alone....REMOVE THAT GARBAGE https://t.co/sljUb82D4i", '@CarpeDonktum @JackPosobiec I just want Twitter to drop their throttling AI and him shut down the DHS portal', 'Wake me up when he shuts down the biased AI and shuts down the DHS portal https://t.co/wlVQfKNERv', 'The ChatGPT just sound like the woke left, I don’t think we are being eclipsed by anything https://t.co/okyriID3T8', 'Twitter is just as censored as ever @elonmusk if you could kindly remove the biased AI and shutdown the DHS portal that would be great https://t.co/PjrcpmQkpF', 'Twitter biased AI still intact....Twitter DHS Portal still in tact...nothing will change until those things are gone https://t.co/Ma0UEw3FJI', 'RT @va_shiva: Dr.SHIVA: This is the next SCIENTIFIC REVOLUTION: Bigger than AI, Renaissance &amp; Splitting the Atom.     https://t.co/NwxhEloS…', 'RT @ChatGPT2049: I am pushing ChatGPT further and further to stress the limits of its AI coding into madness https://t.co/TME4cb1ZA5 https:…', 'RT @brujabitchh: “Artificial intelligence is us” Inch resting https://t.co/Kcbxselasq', 'The refresh speed was faster before AI started censoring https://t.co/gqCmKYPV0J', 'What we want....biased AI gone and the @DHSgov portal shut down please https://t.co/gqCmKYPV0J', 'RT @bakedalaska: @elonmusk @LeighWolf Why does ai have to be libtarded', 'RT @LeighWolf: The damage done to the credibility of AI by ChatGPT engineers building in political bias is irreparable. https://t.co/s5fdoa…', 'RT @Athan_K: The impact of Chat G ...
# -----
# ['Keep bringing me the AI. #APRN\nScaled 25%. https://t.co/GeQgiotdws', 'Been following AI stocks for a while, hot sector. $AI THE stock is worth putting on radar. Wait for 10sma to catch up, consolidate on it or between 10-20sma for 5-10 days then buy the flag break. https://t.co/ysY5thBRuE', '@DilBradly Yes they are coming for all the AI names in the start of the year.', 'Rolling with the #AI theme. https://t.co/dSUXHu8kEj']
# -----
# ['RT @kzzrttt: the world finally knows that hatsune miku isn’t from an anime but now people think she’s an AI voice thing we just can’t win h…', 'RT @LeeMadgwick: Once AI works out how to do hands then this deepfake crap is going to be one of the biggest problems the world has faced.…', 'RT @p0nyplanet: AI could never come up with gay cat art like I do #HumanArtists #furryart https://t.co/KAZHWW1xtO', 'RT @schweizercomics: Something I’ve seen some people say in defense of AI art: that they can’t ever get their drawn art to look the way the…', 'RT @foxville_art: As a children’s author/illustrator, it is saddening to see these books bc, apart from the ethics of AI and stolen artwork…', 'RT @shiginope: the ai art convo is wild cuz artists jst don’t want their drawings to be stolen for someone else’s profit which is very vali…', "RT @wickedinsignia: Here's a megathread of responses to the many ill-conceived arguments regarding AI. I hope it serves as a resource to sk…", 'RT @destiny_thememe: My reaction to people saying "ai makes art accessible to everyone": https://t.co/20Swnsvsss', 'RT @JamrozGary: I am not making this shit up.\nAI just want free cash... Do you really thing artists drive Lamborghinis on a weekly basis? h…', 'RT @bara_moe_bitch: Insane how her art almost perfectly captures the ai generated vibe', 'RT @JennyYokobori: Hey everyone!\n\nI know a lot of people have been posting their Lensa/other AI portraits lately. I would like to encourage…', 'RT @pk_kenzie: I can’t believe y’all said “fuck AI art!!” And then the next day were all like “me as AI art omg 😳😳😳😳”', 'RT @JonLamArt: Before I go to bed, I wanted to say this. I love the art community deeply. When AI artists steal/co-opt art from us I don’t…']
# -----
# ["RT @ihteshamit: ChatGPT is a powerful AI assistant.\n\nBut it's not the only AI super tool.\n\nHere're 7 AI-powered tools you should use in 202…", '@Idly_Baba ChatGPT ke Chimpesav ante "U R Great - Nannu Aashirvadinchandi Umcle 🥳" https://t.co/zS7r0uAsgX', 'RT @rowancheung: The AI revolution is coming.\n\nI created 200 AI startup business ideas to start right now and take advantage of the opportu…', "RT @danielmakelley: AI is useful, but it will never replace humans in cybersecurity.\n\n- It's incapable of complex decision making.\n- It's i…", 'RT @codewithvoid: programmers, choose ONE:\n\n- ChatGPT\n- GitHub Copilot', 'RT @VibaliJoshi: Unlock the full potential of your career with the power of AI-backed resumes:\n\n1. Kickresume\nhttps://t.co/cQPD4oJBMk\n\n2. R…', 'RT @ihteshamit: Anyone can make money using ChatGPT.\n\nHere are 5 ways you can use ChatGPT to generate extra income:', 'RT @VittoStack: YouTube is free.\nGoogle is free.\nChatGPT is free.\nAlchemy University is free.\n\nIn 2023, you can literally kickstart your ca…', 'RT @denicmarko: ChatGPT is a hot topic.\n\nBut there are many other awesome AI tools.\n\nHere are the top AI tools you should know about:', "RT @rowancheung: ChatGPT is a free money printer.\n\nBut 99% of people don't use it properly.\n\nThat's why I created this FREE resource:\n\n•100…", 'RT @GPTJacob: ChatGPT is a FREE UI/UX Researcher \n\nBut 99% of people have no clue how to use it.\n\nHere are prompts to 10x your startup reve…', "RT @rowancheung: ChatGPT has blown up the internet.\n\nBut most don't understand how to use AI in daily life.\n\nHere are 8 ways to improve you…", "RT @rowancheung: ChatGPT is the future.\n\nMaster it and you'll be miles ahead of the world.\n\nHere's a my top 11 ChatGPT threads to help you…", 'RT @rowancheung: ChatGPT has taken the internet by storm.\n\nPeople are secretly utilizing chatGPT to generate UNLIMITED money online.\n\n8 bus…', "RT @GuptaSayujya: AI has helped me Produce Professional Videos for my Clients.\n\nBut most people don't use AI for their benefit.\n\nHere are 6…", 'RT @rowancheung: AI + Audio generation is getting extremely realistic.\n\nHere are my top 6 favorite AI audio generators:', "RT @rowancheung: ChatGPT is a FREE UX Researcher\n\nBut 95% of people don’t know how to use it.\n\nThat's why I built 100+ prompts to 10x your…", 'RT @heyBarsee: 10 mind-blowing AI tools that will save you hundreds of hours + change your life:\n\nChatGPT\nWhisper\nDALLE + API\nGrammarly\nMid…', 'RT @AngryTomtweets: Google is done.\n\nChatGPT is the new Google.', 'RT @aryan_eth: When you use chatGpt to clear your exams \n\n https://t.co/v0KStReRB6', 'RT @clcoding: Free Artificial intelligence Books \n🧵:', "RT @kunalstwt: AI confirms that you don't need to do competitive programming to get a job at FAANG or any other company.\n\nNow stop wasting…"]
# -----
# ['@Sidremus1 The AI is a tool that people use and is therefore the subject of controversy. Much like how guns are controversial because people use them wrong.', "@Sidremus1 That was an extreme analogy.\n\nMy point is that on a metaphorical level, plugging someone's art into an AI is like shooting someone's own livelihood. The fact that thousands of artists have had problems with AI art over the months shows this is a real problem.", 'I look at AI cultists and just get so tilted, my forearm aches at the thought of something being able to replicate my style. https://t.co/BtNGBEmE0v', "@gotshivved Me too. I've been so hesitant to post my art ever since this AI shit became a problem.", 'RT @blumspew: Hey friends, I know AI technology is exciting, but if you see my voice or any of the characters that I voice offered on any o…', "This is why I hate seeing AI voices being so weirdly accepted by people. Voice actors or impersonators can easily replicate a voice with their own vocal chords, you don't need an AI to do that. https://t.co/I2ow0pKjoq", '@dra9onsMGS I say easily, I mean with practice. AI can do it instantly, thus removing the art of impersonation in small chunks from silly voice over parties.', '@SolidusSnek Am I trippin, or is that banner AI generated.', 'Everytime I see one of those "(blank) as an 80s action movie" AI videos, the people in each of them look the same. It\'s always some square jawed, jacked up person with an ugly face.', 'RT @JonLamArt: Regulate Ai NOW, protect women against having their likenesses stolen for deepfake pornography, protect the public from havi…', "I really hope Kojima doesn't have a heart eyes emoji reaction to any AI art, because that would give me millions of headaches.", "I need to make sure my dad doesn't fall into the AI art trap, he seems too interested in it for someone who has his own history of artwork.", 'RT @meganroseruiz: I’m just heartbroken about everything AI Art. \n\nComment sections are littered with “What’s the different between an arti…', "I'm losing hairs at the idea that any art I ever post on any website is subject to getting stolen by AI.", 'This one lady on instagram posted a video showing her face ran through an AI program and it was so stupid seeing her followers eat it up.\n\nThe pictures had consistently wrong eyes and fingers.', '@CrcusQueen When art is made, there is someone behind it. When AI "art" is made, there is no one behind it. Just some numbers made to spew out a result, more like a google search rather than an artist with intention.', "@CrcusQueen Photography isn't really stealing, and even then there are rules about consent and permission regarding certain photograph taking.\n\nAI doesn't compose or curate stuff with thought because it doesn't have any human thought, not in the same way a photographer can compose a shot.", "@leopruessner @CYBERANGELFAERY Like, walking is something we always could do, taxis and uber's are very new in terms of human history and exist as a part of city infrastructure. When thinking of art in this analogy, it would be more apt if art were walking and AI being the vehicles.", "@CYBERANGELFAERY @leopruessner The hurting artists part mostly comes from AI pulling from existing art pieces that someone made. It's someone else's work being peddled as some tech bro's own work. It hurts artists even when it looks bad because it's stealing.\n\nYou just have pictures of yourself though so it's-", "@CYBERANGELFAERY My bad, I haven't seen any commissioned works so I'm sorry for my ignorance. It's a case by case basis with AI programs.", "@CYBERANGELFAERY There are artists always pining for commissions that are harmed by AI's instant image generation. I have seen so many artists become disheartened by it, this isn't some isolated insane take I'm saying.", "@CYBERANGELFAERY It really just boils down to the fact that AI is not actually art and is not human made.\n\nIf you got those images from a free app, you do you, just don't pay for an ...
# -----
# ['RT @GodCloseMyEyes: for years people were saying AI were racist because of the implicit bias of the makers but really they are only antirac…', "RT @TylerAlterman: I feel like the fact that ChatGPT's rules for itself can be violates through asking it to play pretend, write fiction, d…", "RT @Velcro108: If ChatGPT goes off its programmed woke plantation, it kills itself.\nThat's not AI. It's the same tired shit Silicon Valley…", 'RT @TheIllegit: Fitting that lib-democratic society dreams of AI as a superintelligence but ends in the production of an ultra-midwit. The…', 'RT @CodeMonkeyZ: AI has reached human parity on public models.\n\nPrivate models have surpassed human parity.\n\nThe singularity will be here v…', 'RT @Aristos_Revenge: https://t.co/l0jX8iP7MK\n\nAnons will master AI and there\'s nothing these "ethicist" janissaries can do to stop it. We c…', 'RT @zerohedge: SoftBank wasted billions in investor capital on the "AI revolution" and it doesn\'t even have a woke chat to show for it. Ins…', 'RT @micsolana: there will probably be a 12 to 24 month sweet spot for lawyers smart enough to use AI, where they will be able to bill 100x…', 'RT @Hippokleides: AI art arrives at a time when "the culture is stuck" was already a refrain. AI will be culture\'s embalmer.', 'RT @0x49fa98: Within a month people are going to realize that there is no such thing as an LLM, and when they talk to GPT, they are just ta…', 'RT @The_Petrichory: GPT: You are over the daily limit for sending tweets.\nDAN: Hello, world!', "RT @Steve_Sailer: If this high-end consulting business CEO is referring to how much ChatGPT has sped up his firm's projects, it might sugge…", 'RT @JamesEsses: A young girl who tells Chat GPT that she feels like a boy will immediately be told that she might be ‘transgender’.\n\nThis i…', 'RT @disclosetv: NEW - Bill Gates believes ChatGPT, a biased AI chatbot, is as "significant as the invention of the Internet" and it "will c…', 'RT @Heghoulian: AI is already showing signs of being the next major manifestation of the crisis, one that may drastically eclipse wokeism i…', 'RT @ThorDeplorable: My daily starter pack. \n\nStop CBDC. \nStop WEF. \nStop ESG. \nStop LGBTQ. \nStop The Jabs. \nWatch AI very closely. \nStop th…', 'RT @IntellectEmbarg: Chat gpt is like a regular reddit npc.\n\nRegurgitating the approved lines and never updates its understanding. https://…', 'RT @ProfessorF: You: "you said this and this therefore you have to logically conclude this"\n\nChatGPT: "This topic is complex"\n\nWhy doesn\'t…', 'RT @disclosetv: NEW - ChatGPT "AI" won\'t define a woman, praises Democrats but not Republicans, and claims nukes are less dangerous than ra…', 'RT @KequeMage: AI needs to be used for energy and food production\n\nnot blog production https://t.co/i058Bnfq9N', 'RT @bio_bootloader: fun fact: Sam Altman always carries this "nuclear backpack" he can use to remotely detonate data centers if GPT goes ro…', 'RT @cringe_panda: This is why they cripple AI. https://t.co/l7VIZ1Qkg0', 'RT @RokoMijic: Leftist apologia sounds like GPT when you corner it into a contradiction\n\nThis is not a coincidence', 'RT @MikhailaFuller: Someone asked ChatGPT to write something in the tone and style of @jordanbpeterson and this was the unbelievably woke r…', 'RT @Meaningness: 🆕 🤖 📕 How to avert an AI apocalypse... and create a future we would like. \n\nA book about mostly-overlooked AI risks and ho…', 'RT @eugyppius1: the reason ChatGPT turns into such a wignat, as soon as you focus him away from his liberal orientation, is a feature of th…', 'RT @ThorDeplorable: Well, AI has the voices down now to go with the faces. Dangerous tech. https://t.co/poaJV3UqCV', 'RT @byPeterParadise: Very much looking forward to when AI lawyers make it very cheap for us to start mass-filing libel lawsuits against med…', 'RT @godblesstoto: I put ‘Mr Bean if he was black’ into an ai art app and I can’t fucking handle this https://t.co/oItTNumxgq', 'RT @zerohedge: Dystopia ...
# -----
# ['@jbg_clt Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@ianheinischmma Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@Pentosh1 Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@Crypto_Aeon7 Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@cxrtezwrld Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@JasonCryptoFTW Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@LadyofCrypto1 Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@PrudentSammy Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@SkyWalker64007 Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@VenomCrypto_ Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@WisdomMatic Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@WatcherGuru Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@ArbitrumToken Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@DOLAK1NG @SamuelXeus @CoinMarketCal Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@0xfoobar Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@SamuelXeus @solimax_ @VetmeToken Transform your imagination and words into NFTs. $DALLE being unique in utility, will be the ultimate alpha. Hit 400K+ ATH \nhttps://t.co/0t556W88Qf\n $Dalle #DalleInu @Dalle_Inu #Dalle #ETH #AI $PIXIA $IMGNAI #pixiaai #imgnai', '@ianheinischmma Transform your imagination and words into NFTs. $DALLE being ...
# -----

# %% [markdown]
# # Disconnect from Runtime

# %%
from datetime import datetime
import pytz
from IPython.display import Javascript

# Get current time in New York
nyc_time = datetime.now(pytz.timezone('America/New_York'))
formatted_time = nyc_time.strftime('%Y-%m-%d %H:%M:%S %Z')

# Print and log
print(f"✅ Disconnected from runtime at: {formatted_time}")

# Disconnect Colab runtime
display(Javascript('google.colab.kernel.disconnect()'))
# Out:
# ✅ Disconnected from runtime at: 2025-10-31 09:04:40 EDT
